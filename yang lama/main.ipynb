# %%
# Install library yang diperlukan (jalankan sekali)
#%pip install fuzzywuzzy python-Levenshtein pandas

import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import warnings
warnings.filterwarnings('ignore')

print("Library berhasil diimport!")
# Out:
# Library berhasil diimport!

# %%
# Load data dari ketiga CSV
peserta_mcf_df = pd.read_csv('peserta mcf.csv')
peserta_mos_df = pd.read_csv('peserta mos.csv')
certiport_df = pd.read_csv('certiport.csv', skiprows=4)  # Skip 4 baris header kosong

# Bersihkan kolom certiport (hapus kolom kosong)
certiport_df = certiport_df.dropna(axis=1, how='all')

# Tambahkan kolom untuk membedakan sumber data
peserta_mcf_df['Sumber'] = 'MCF'
peserta_mos_df['Sumber'] = 'MOS'

# Gabungkan kedua data peserta
peserta_df = pd.concat([peserta_mcf_df, peserta_mos_df], ignore_index=True)

# Filter data certiport berdasarkan Exam
# MCF: AI-900: Microsoft Azure AI Fundamentals
# MOS: Yang mengandung "Office 2019" (Word, Excel, PowerPoint)
certiport_mcf = certiport_df[certiport_df['Exam'].str.contains('AI-900', na=False)].copy()
certiport_mos = certiport_df[certiport_df['Exam'].str.contains('Office 2019', na=False)].copy()

# Tambahkan kolom sumber untuk certiport
certiport_mcf['Sumber_Certiport'] = 'MCF'
certiport_mos['Sumber_Certiport'] = 'MOS'

print(f"=" * 70)
print("DATA PESERTA PENDAFTAR")
print(f"=" * 70)
print(f"Jumlah peserta MCF (Azure AI-900): {len(peserta_mcf_df)}")
print(f"Jumlah peserta MOS (Office 2019): {len(peserta_mos_df)}")
print(f"Total peserta: {len(peserta_df)}")

print(f"\n{'=' * 70}")
print("DATA CERTIPORT (HASIL UJIAN)")
print(f"=" * 70)
print(f"Total data di Certiport: {len(certiport_df)}")
print(f"Data MCF (AI-900): {len(certiport_mcf)}")
print(f"Data MOS (Office 2019): {len(certiport_mos)}")

print(f"\n--- Exam yang tersedia di Certiport ---")
print(certiport_df['Exam'].value_counts())

print(f"\n--- Preview Data Certiport MCF ---")
print(certiport_mcf[['First Name', 'Last Name', 'Exam', 'Result']].head())
print(f"\n--- Preview Data Certiport MOS ---")
print(certiport_mos[['First Name', 'Last Name', 'Exam', 'Result']].head())
# Out:
# ======================================================================
# DATA PESERTA PENDAFTAR
# ======================================================================
# Jumlah peserta MCF (Azure AI-900): 56
# Jumlah peserta MOS (Office 2019): 101
# Total peserta: 157
#
# ======================================================================
# DATA CERTIPORT (HASIL UJIAN)
# ======================================================================
# Total data di Certiport: 4853
# Data MCF (AI-900): 897
# Data MOS (Office 2019): 3445
#
# --- Exam yang tersedia di Certiport ---
# Exam
# Microsoft Word (Office 2019)                                         2714
# AI-900: Microsoft Azure AI Fundamentals                               897
# Microsoft Excel (Office 2019)                                         624
# Microsoft Word (Office 2016)                                          287
# Microsoft Excel (Office 2016)                                         161
# Microsoft PowerPoint (Office 2019)                                    104
# Microsoft PowerPoint (Office 2016)                                     53
# Microsoft Word Expert (Office 2019)                                     3
# Microsoft Excel (Microsoft 365 Apps)                                    2
# Microsoft Word (Microsoft 365 Apps)                                     1
# SC-900: Microsoft Security, Compliance, and Identity Fundamentals       1
# Name: count, dtype: int64
#
# --- Preview Data Certiport MCF ---
#                First Name      Last Name  \
# 0           NIKITA ANJANI      ALFARIANI
# 1  NI KADEK WINDA CHRISTY       FEBRIANI
# 2                   LULUK        PARWATI
# 3                 BASKARA  DASA RAMADHAN
# 4            HADI ARRIJAL         HENDRI
#
#                                       Exam Result
# 0  AI-900: Microsoft Azure AI Fundamentals   Fail
# 1  AI-900: Microsoft Azure AI Fundamentals   Fail
# 2  AI-900: Microsoft Azure AI Fundamentals   Fail
# 3  AI-900: Microsoft Azure AI Fundamentals   Fail
# 4  AI-900: Microsoft Azure AI Fundamentals   Pass
#
# --- Preview Data Certiport MOS ---
#        First Name         Last Name                          Exam Result
# 35    Atha Habibi           Gunanda  Microsoft Word (Office 2019)   Pass
# 36           Ivan   Arfianto Rahman  Microsoft Word (Office 2019)   Pass
# 37  Muhamad Fauzi             Akbar  Microsoft Word (Office 2019)   Pass
# 38         Nabila      Asyifa Qalbi  Microsoft Word (Office 2019)   Fail
# 39         Reihan  Muhammad Ghossan  Microsoft Word (Office 2019)   Pass

# %%
# Fungsi untuk normalisasi nama (lowercase, hapus spasi berlebih)
def normalize_name(name):
    if pd.isna(name):
        return ""
    # Hapus karakter khusus kecuali huruf, angka, spasi, dan titik
    cleaned = ''.join(c for c in str(name) if c.isalnum() or c.isspace() or c == '.')
    return ' '.join(cleaned.upper().strip().split())

# Fungsi untuk membalik urutan nama (antisipasi nama terbalik)
def reverse_name(name):
    parts = name.split()
    if len(parts) >= 2:
        # Coba balik first name dan last name
        return ' '.join(parts[::-1])
    return name

# Fungsi untuk menghitung jumlah kata yang cocok
def count_matching_words(name1, name2, min_word_length=2):
    """
    Menghitung jumlah kata yang sama antara dua nama.
    Hanya menghitung kata dengan panjang minimal min_word_length.
    """
    words1 = set(w for w in name1.split() if len(w) >= min_word_length)
    words2 = set(w for w in name2.split() if len(w) >= min_word_length)
    return len(words1.intersection(words2))

# Fungsi fuzzy matching dengan berbagai strategi + filter minimal 2 kata cocok
def find_best_match(peserta_name, certiport_names, threshold=80, min_matching_words=2):
    """
    Mencari kecocokan terbaik dengan berbagai strategi:
    1. Exact match
    2. Fuzzy match pada full name
    3. Fuzzy match pada nama terbalik
    4. Token set ratio (mengabaikan urutan kata)
    
    PENTING: Minimal harus ada 2 kata yang cocok untuk dianggap match
    """
    peserta_normalized = normalize_name(peserta_name)
    
    # 1. Exact match
    if peserta_normalized in certiport_names:
        return peserta_normalized, 100, "Exact Match"
    
    # 2. Cek nama terbalik exact
    reversed_name = reverse_name(peserta_normalized)
    if reversed_name in certiport_names:
        return reversed_name, 100, "Exact Match (Nama Terbalik)"
    
    best_score = 0
    best_match = None
    match_type = ""
    best_word_count = 0
    
    for cert_name in certiport_names:
        # Hitung jumlah kata yang cocok
        matching_words = count_matching_words(peserta_normalized, cert_name)
        
        # Skip jika kata yang cocok kurang dari minimum
        if matching_words < min_matching_words:
            continue
        
        # Fuzzy ratio normal
        score1 = fuzz.ratio(peserta_normalized, cert_name)
        # Token set ratio (tidak peduli urutan kata)
        score2 = fuzz.token_set_ratio(peserta_normalized, cert_name)
        # Token sort ratio
        score3 = fuzz.token_sort_ratio(peserta_normalized, cert_name)
        # Partial ratio
        score4 = fuzz.partial_ratio(peserta_normalized, cert_name)
        
        # Ambil skor tertinggi
        max_score = max(score1, score2, score3, score4)
        
        # Prioritaskan yang punya lebih banyak kata cocok, lalu skor tertinggi
        if matching_words > best_word_count or (matching_words == best_word_count and max_score > best_score):
            best_score = max_score
            best_match = cert_name
            best_word_count = matching_words
            if max_score == score1:
                match_type = "Fuzzy Ratio"
            elif max_score == score2:
                match_type = "Token Set Ratio"
            elif max_score == score3:
                match_type = "Token Sort Ratio"
            else:
                match_type = "Partial Ratio"
    
    if best_score >= threshold and best_word_count >= min_matching_words:
        return best_match, best_score, f"{match_type} ({best_word_count} kata cocok)"
    
    return None, best_score, "Tidak Ditemukan"

print("Fungsi matching berhasil dibuat!")
print("Filter: Minimal 2 kata yang cocok untuk dianggap match")
# Out:
# Fungsi matching berhasil dibuat!
# Filter: Minimal 2 kata yang cocok untuk dianggap match

# %%
# ========== PISAHKAN PESERTA BERDASARKAN STATUS ==========
print(f"=" * 70)
print("PEMISAHAN DATA BERDASARKAN STATUS REGISTRASI")
print(f"=" * 70)

# Pisahkan peserta APPROVED dan NOT APPROVED
approved_df = peserta_df[peserta_df['Status'] == 'APPROVED'].copy()
not_approved_df = peserta_df[peserta_df['Status'] == 'NOT APPROVED'].copy()

print(f"Total peserta: {len(peserta_df)}")
print(f"  - Status APPROVED: {len(approved_df)} orang (tidak perlu di-crosscheck)")
print(f"  - Status NOT APPROVED: {len(not_approved_df)} orang (perlu di-crosscheck)")
print()

# ========== PROSES CROSS-CHECK HANYA UNTUK NOT APPROVED ==========
print(f"{'=' * 70}")
print("PROSES CROSS-CHECK UNTUK PESERTA NOT APPROVED")
print(f"=" * 70)

# Buat Full Name untuk certiport
certiport_mcf['Full Name'] = certiport_mcf['First Name'].fillna('') + ' ' + certiport_mcf['Last Name'].fillna('')
certiport_mos['Full Name'] = certiport_mos['First Name'].fillna('') + ' ' + certiport_mos['Last Name'].fillna('')

# Normalisasi nama certiport
certiport_mcf_names = [normalize_name(name) for name in certiport_mcf['Full Name'].tolist()]
certiport_mos_names = [normalize_name(name) for name in certiport_mos['Full Name'].tolist()]

# Hasil matching (HANYA UNTUK NOT APPROVED)
results = []

for idx, row in not_approved_df.iterrows():
    peserta_name = row['Nama']
    status_peserta = row['Status']
    sumber_data = row['Sumber']
    program = row['Program Dipilih']
    
    # Pilih data certiport sesuai sumber
    if sumber_data == 'MCF':
        certiport_names = certiport_mcf_names
    else:  # MOS
        certiport_names = certiport_mos_names
    
    match, score, match_type = find_best_match(peserta_name, certiport_names)
    
    results.append({
        'Nama Peserta': peserta_name,
        'NIM': row['NIM'],
        'Jurusan': row['Jurusan'],
        'Sumber Data': sumber_data,
        'Program': program,
        'Status Registrasi': status_peserta,
        'Nama di Certiport': match if match else '-',
        'Skor Kecocokan': score,
        'Tipe Match': match_type,
        'Status Certiport': '✅ DITEMUKAN' if match else '❌ TIDAK DITEMUKAN'
    })

# Buat DataFrame hasil (HANYA NOT APPROVED)
results_df = pd.DataFrame(results)
print(f"Proses cross-check selesai untuk {len(results)} peserta NOT APPROVED!")
print(f"\n--- Ringkasan Hasil Cross-Check (NOT APPROVED) ---")
print(results_df['Status Certiport'].value_counts())
print(f"\nBerdasarkan Sumber Data:")
print(results_df.groupby(['Sumber Data', 'Status Certiport']).size().unstack(fill_value=0))
# Out:
# ======================================================================
# PEMISAHAN DATA BERDASARKAN STATUS REGISTRASI
# ======================================================================
# Total peserta: 157
#   - Status APPROVED: 85 orang (tidak perlu di-crosscheck)
#   - Status NOT APPROVED: 72 orang (perlu di-crosscheck)
#
# ======================================================================
# PROSES CROSS-CHECK UNTUK PESERTA NOT APPROVED
# ======================================================================
# Proses cross-check selesai untuk 72 peserta NOT APPROVED!
#
# --- Ringkasan Hasil Cross-Check (NOT APPROVED) ---
# Status Certiport
# ✅ DITEMUKAN          52
# ❌ TIDAK DITEMUKAN    20
# Name: count, dtype: int64
#
# Berdasarkan Sumber Data:
# Status Certiport  ✅ DITEMUKAN  ❌ TIDAK DITEMUKAN
# Sumber Data
# MCF                         3                 10
# MOS                        49                 10

# %%
# ========== HASIL: PESERTA YANG DITEMUKAN DI CERTIPORT ==========
found_df = results_df[results_df['Status Certiport'] == '✅ DITEMUKAN'].copy()
print(f"=" * 70)
print(f"PESERTA YANG DITEMUKAN DI CERTIPORT: {len(found_df)} orang")
print(f"=" * 70)
print(found_df[['Nama Peserta', 'NIM', 'Sumber Data', 'Program', 'Status Registrasi', 'Nama di Certiport', 'Skor Kecocokan']].to_string(index=False))
print()
# Out:
# ======================================================================
# PESERTA YANG DITEMUKAN DI CERTIPORT: 52 orang
# ======================================================================
#                       Nama Peserta       NIM Sumber Data           Program Status Registrasi                  Nama di Certiport  Skor Kecocokan
#            MUHAMMAD RAFI AL ANBIYA 202231089         MCF MCF: Azure AI-900      NOT APPROVED               MUHAMMAD RAFI FARHAN              85
#          MUHAMMAD RIFQI APRIANSYAH 202231104         MCF MCF: Azure AI-900      NOT APPROVED                     MUHAMMAD RIFQI             100
#               UMMU PUTRI SALSABILA 202232036         MCF MCF: Azure AI-900      NOT APPROVED                SALSABILA EKA PUTRI              88
#               RAIHAN CANDRA IRAWAN 202211117         MOS        MOS: Excel      NOT APPROVED                      RAIHAN IRAWAN             100
#                    MUHAMMAD RAIHAN 202241017         MOS        MOS: Excel      NOT APPROVED                    MUHAMMAD RAIHAN             100
# MUHAMMAD REVIANSYAH DANENDRA PUTRA 202131160         MOS         MOS: Word      NOT APPROVED MUHAMMAD REVIANSYAH DANENDRA PUTRA             100
#    DHEA HERAWATI INDAH PUTRI ERWIN 202231088         MOS        MOS: Excel      NOT APPROVED          DHEA HERAWATI PUTRI ERWIN             100
#          ANDI MUHAMMAD NABIL ALKAF 202231112         MOS         MOS: Word      NOT APPROVED                     MUHAMMAD NABIL             100
#                BINTAR ANDIKA PUTRA 202211113         MOS         MOS: Word      NOT APPROVED                       BINTAR PUTRA             100
#           RACHMAD FAQIH AFGIANSYAH 202112050         MOS         MOS: Word      NOT APPROVED           RACHMAD FAQIH AFGIANSYAH             100
#                      JIHAN DIOVANT 202212037         MOS         MOS: Word      NOT APPROVED              JIHAN AZZAHRA DIOVANT             100
#                NADELLA EZI SABRINA 202232010         MOS         MOS: Word      NOT APPROVED                    NADELLA SABRINA             100
#             JOHN ANDREW TAMPUBOLON 202211153         MOS         MOS: Word      NOT APPROVED             JOHN ANDREW TAMPUBOLON             100
#           SARIFA ARINI LATUCONSINA 202231041         MOS        MOS: Excel      NOT APPROVED                 SARIFA LATUCONSINA             100
#                   AHMAD TRI STIADI 202211101         MOS        MOS: Excel      NOT APPROVED                       AHMAD STIADI             100
#                  DAVID AJI PRAYOGA 202211050         MOS         MOS: Word      NOT APPROVED                      DAVID PRAYOGA             100
#            TARISA DWINA ARTHANEVIA 202232022         MOS         MOS: Word      NOT APPROVED                  TARISA ARTHANEVIA             100
#       MUHAMMAD RIZKY BAMBY SAPUTRA 202232002         MOS         MOS: Word      NOT APPROVED             MUHAMMAD RIZKY SAPUTRA             100
#            ARIO YOGATAMA ERLAPUTRA 202242012         MOS        MOS: Excel      NOT APPROVED                     ARIO ERLAPUTRA             100
#                      SANDIKA NAMBO 202011201         MOS         MOS: Word      NOT APPROVED                SANDIKA LAODE NAMBO             100
#               BAIQ PUTRI SUARTIKHA 202232023         MOS         MOS: Word      NOT APPROVED                     BAIQ SUARTIKHA             100
#              JUAN GERALD ARITONANG 202232007         MOS         MOS: Word      NOT APPROVED                     JUAN ARITONANG             100
#                    DIMAS DAMARJATI 202231020         MOS   MOS: PowerPoint      NOT APPROVED                    DIMAS DAMARJATI             100
#                INAYAH ANANDA PUTRI 202221011         MOS        MOS: Excel      NOT APPROVED                       INAYAH PUTRI             100
#     I GEDE PUTU BAGUS KRISNA PANDE 202231042         MOS        MOS: Excel      NOT APPROVED                  I GEDE PUTU PANDE             100
#          KOMANG ARYA DIVA PRAMARTA 202211008         MOS        MOS: Excel      NOT APPROVED                        KOMANG ARYA             100
#       I MADE DWI MAHA PUTRA SUJANA 202211012         MOS        MOS: Excel      NOT APPROVED                      I MADE SUJANA             100
#              WAHID YAMINSYAH PUTRA 202231040         MOS        MOS: Excel      NOT APPROVED                        WAHID PUTRA             100
#                    GALIH RAKA SIWI 202231060         MOS        MOS: Excel      NOT APPROVED                         GALIH SIWI             100
#               AKMAL DZAKY ADHYNATA 202212031         MOS         MOS: Word      NOT APPROVED                     AKMAL ADHYNATA             100
#          RADEN MUHAMMAD ASYAM RAFI 202211042         MOS         MOS: Word      NOT APPROVED               MUHAMMAD RAFI FARHAN              80
#           DWIANTORO AZKA NAYOTTAMA 202212039         MOS         MOS: Word      NOT APPROVED                DWIANTORO NAYOTTAMA             100
#           SYAIFULLAH YUSUF SAPUTRA 202212523         MOS         MOS: Word      NOT APPROVED           SYAIFULLAH YUSUF SAPUTRA             100
#           SARAH AISYAH KUSUMAHARJO 202211086         MOS         MOS: Word      NOT APPROVED                  SARAH KUSUMAHARJO             100
#             MUHAMMAD SADDAM WIJAYA 202011316         MOS         MOS: Word      NOT APPROVED                    MUHAMMAD WIJAYA             100
#                   ZAKI RIZALUL HAQ 202214007         MOS   MOS: PowerPoint      NOT APPROVED                   ZAKI RIZALUL HAQ             100
#                     RIZKY RAMADHAN 202212038         MOS         MOS: Word      NOT APPROVED                     RIZKY RAMADHAN             100
#                  DANI ABID ASSINDI 202211079         MOS         MOS: Word      NOT APPROVED                       DANI ASSINDI             100
#            MUHAMMAD NOFRAN SAPUTRA 202211082         MOS         MOS: Word      NOT APPROVED                   MUHAMMAD SAPUTRA             100
#               AZHAR LAZUARDI IMANI 202211136         MOS         MOS: Word      NOT APPROVED                        AZHAR IMANI             100
#        ROVAN LUWID ERVAN SIHOMBING 202212002         MOS        MOS: Excel      NOT APPROVED                    ROVAN SIHOMBING             100
#                 HABIL RAMA TAUFANY 202231077         MOS        MOS: Excel      NOT APPROVED                      HABIL TAUFANY             100
#              MUHAMMAD NAUFAL ARIEF 202231026         MOS         MOS: Word      NOT APPROVED              MUHAMMAD NAUFAL ARIEF             100
#             MUHAMMAD DAFFA ZHAFRAN 202211115         MOS         MOS: Word      NOT APPROVED               MUHAMMAD DAFFA JOWIS              82
#                       AZRA OKSYANI 202212012         MOS         MOS: Word      NOT APPROVED                       AZRA OKSYANI             100
#              MUHAMMAD RAFI PRATAMA 202211141         MOS         MOS: Word      NOT APPROVED                   MUHAMMAD PRATAMA             100
#               ZAGHI PRIMA MANGGALA 202242006         MOS         MOS: Word      NOT APPROVED                     ZAGHI MANGGALA             100
#                   M RIZKY RAMADHAN 202231065         MOS        MOS: Excel      NOT APPROVED                     RIZKY RAMADHAN             100
#                      MUHAMMAD RAFI 202231036         MOS         MOS: Word      NOT APPROVED               MUHAMMAD RAFI FARHAN             100
#                 RISHA FIRLY APSARI 202242022         MOS         MOS: Word      NOT APPROVED                       RISHA APSARI             100
#                   LASMA DEVI ARUAN 202111143         MOS        MOS: Excel      NOT APPROVED                        LASMA ARUAN             100
#                  SURYA ADI SAPUTRA 202111150         MOS         MOS: Word      NOT APPROVED                  SURYA ADI SAPUTRA             100

# %%
# ========== HASIL: PESERTA YANG TIDAK DITEMUKAN DI CERTIPORT ==========
# Filter hanya yang status "NOT APPROVED" saja (sesuai data MCF/MOS)
not_found_df = results_df[
    (results_df['Status Certiport'] == '❌ TIDAK DITEMUKAN') & 
    (results_df['Status Registrasi'] == 'NOT APPROVED')
].copy()

print(f"=" * 70)
print(f"PESERTA NOT APPROVED YANG TIDAK DITEMUKAN DI CERTIPORT: {len(not_found_df)} orang")
print(f"=" * 70)
if len(not_found_df) > 0:
    print(not_found_df[['Nama Peserta', 'NIM', 'Sumber Data', 'Program', 'Status Registrasi', 'Skor Kecocokan']].to_string(index=False))
else:
    print("Semua peserta dengan status NOT APPROVED sudah ditemukan di Certiport!")
print()

# Tampilkan juga semua yang tidak ditemukan (semua status)
not_found_all_df = results_df[results_df['Status Certiport'] == '❌ TIDAK DITEMUKAN'].copy()
print(f"\n[INFO] Total peserta tidak ditemukan (semua status): {len(not_found_all_df)} orang")
print("Breakdown berdasarkan Status Registrasi:")
print(not_found_all_df['Status Registrasi'].value_counts().to_string())
# Out:
# ======================================================================
# PESERTA NOT APPROVED YANG TIDAK DITEMUKAN DI CERTIPORT: 20 orang
# ======================================================================
#                         Nama Peserta       NIM Sumber Data           Program Status Registrasi  Skor Kecocokan
#                   HABIL RAMA TAUFANY 202231077         MCF MCF: Azure AI-900      NOT APPROVED               0
#                    LUTFIANSYAH MAJID 202131129         MCF MCF: Azure AI-900      NOT APPROVED               0
#                 KASHRINA MASYID AZKA 202231055         MCF MCF: Azure AI-900      NOT APPROVED               0
#                MUHAMMAD NAUFAL ARIEF 202231026         MCF MCF: Azure AI-900      NOT APPROVED               0
#       DESTA AZRA ROSANI FEERLIAN ADI 202232033         MCF MCF: Azure AI-900      NOT APPROVED               0
#                     POPY LEONI PURBA 202231079         MCF MCF: Azure AI-900      NOT APPROVED               0
# SERLINA MARGARET BANOET BR HUTAHAEAN 202131161         MCF MCF: Azure AI-900      NOT APPROVED               0
#                         DEWI SAFITRI 202231011         MCF MCF: Azure AI-900      NOT APPROVED               0
#                       GRACE HUTASOIT 202231082         MCF MCF: Azure AI-900      NOT APPROVED               0
#                 AFFANDI MUFTI NASRUN 201831201         MCF MCF: Azure AI-900      NOT APPROVED               0
#            MUHAMMAD ALLIF HABIBILLAH 202242014         MOS         MOS: Word      NOT APPROVED               0
#                       CARLOS LIMBONG 202112036         MOS         MOS: Word      NOT APPROVED               0
#                      NADYARA NATASHA 202232009         MOS         MOS: Word      NOT APPROVED               0
#                  IBNU RASYID AL FAIZ 202232028         MOS        MOS: Excel      NOT APPROVED              59
#                   SEPTIAN DWI ANDANA 202214009         MOS         MOS: Word      NOT APPROVED               0
#          LORENZO GONZALEZ SITUMORANG 201931071         MOS         MOS: Word      NOT APPROVED               0
#                   MICKY IKHSAN ASRIL 201911059         MOS         MOS: Word      NOT APPROVED               0
#               ANDI XAVIER WIDYADHANA 202231052         MOS         MOS: Word      NOT APPROVED               0
#                         DHIAZ ADITYA 202212040         MOS         MOS: Word      NOT APPROVED               0
#     MUHAMMAD VIRGIAWAN PUTRA KARMAJI 202232034         MOS        MOS: Excel      NOT APPROVED              76
#
#
# [INFO] Total peserta tidak ditemukan (semua status): 20 orang
# Breakdown berdasarkan Status Registrasi:
# Status Registrasi
# NOT APPROVED    20

# %%
# ========== RINGKASAN STATISTIK ==========
print(f"=" * 70)
print("RINGKASAN LENGKAP")
print(f"=" * 70)
print(f"Total peserta dari registrasi   : {len(peserta_df)}")
print(f"  - Status APPROVED             : {len(approved_df)} orang")
print(f"  - Status NOT APPROVED         : {len(not_approved_df)} orang")
print(f"\nTotal data di Certiport         : {len(certiport_df)}")
print(f"  - MCF (AI-900)                : {len(certiport_mcf)}")
print(f"  - MOS (Office 2019)           : {len(certiport_mos)}")
print(f"-" * 70)
print("HASIL CROSS-CHECK (HANYA NOT APPROVED):")
print(f"✅ Ditemukan di Certiport       : {len(found_df)} ({len(found_df)/len(not_approved_df)*100:.1f}% dari NOT APPROVED)")
print(f"❌ Tidak ditemukan di Certiport : {len(not_found_all_df)} ({len(not_found_all_df)/len(not_approved_df)*100:.1f}% dari NOT APPROVED)")
print(f"=" * 70)

# Breakdown berdasarkan tipe match
print("\nBreakdown berdasarkan tipe kecocokan:")
print(results_df['Tipe Match'].value_counts().to_string())

# Breakdown berdasarkan sumber data
print("\nBreakdown hasil cross-check berdasarkan Sumber Data:")
pivot = results_df.groupby(['Sumber Data', 'Status Certiport']).size().unstack(fill_value=0)
print(pivot.to_string())
# Out:
# ======================================================================
# RINGKASAN LENGKAP
# ======================================================================
# Total peserta dari registrasi   : 157
#   - Status APPROVED             : 85 orang
#   - Status NOT APPROVED         : 72 orang
#
# Total data di Certiport         : 4853
#   - MCF (AI-900)                : 897
#   - MOS (Office 2019)           : 3445
# ----------------------------------------------------------------------
# HASIL CROSS-CHECK (HANYA NOT APPROVED):
# ✅ Ditemukan di Certiport       : 52 (72.2% dari NOT APPROVED)
# ❌ Tidak ditemukan di Certiport : 20 (27.8% dari NOT APPROVED)
# ======================================================================
#
# Breakdown berdasarkan tipe kecocokan:
# Tipe Match
# Token Set Ratio (2 kata cocok)    37
# Tidak Ditemukan                   20
# Exact Match                       11
# Token Set Ratio (3 kata cocok)     2
# Partial Ratio (2 kata cocok)       1
# Token Set Ratio (4 kata cocok)     1
#
# Breakdown hasil cross-check berdasarkan Sumber Data:
# Status Certiport  ✅ DITEMUKAN  ❌ TIDAK DITEMUKAN
# Sumber Data
# MCF                         3                 10
# MOS                        49                 10

# %%
# ========== EXPORT HASIL KE CSV ==========
print(f"\n{'=' * 70}")
print("EXPORT HASIL KE FILE CSV")
print(f"=" * 70)

# 1. Export peserta APPROVED (langsung diterima, tidak perlu crosscheck)
approved_df.to_csv('peserta_approved.csv', index=False, encoding='utf-8-sig')

# 2. Export semua hasil cross-check (NOT APPROVED)
results_df.to_csv('hasil_crosscheck_not_approved.csv', index=False, encoding='utf-8-sig')

# 3. Export NOT APPROVED yang ditemukan di Certiport
found_df.to_csv('peserta_not_approved_ditemukan.csv', index=False, encoding='utf-8-sig')

# 4. Export NOT APPROVED yang tidak ditemukan di Certiport
not_found_all_df.to_csv('peserta_not_approved_tidak_ditemukan.csv', index=False, encoding='utf-8-sig')

print("✅ File hasil telah disimpan:")
print(f"\n📁 PESERTA APPROVED (Langsung Diterima):")
print(f"   1. peserta_approved.csv")
print(f"      → {len(approved_df)} peserta dengan status APPROVED")
print(f"\n📁 HASIL CROSS-CHECK NOT APPROVED:")
print(f"   2. hasil_crosscheck_not_approved.csv")
print(f"      → Semua hasil cross-check peserta NOT APPROVED ({len(results_df)} peserta)")
print(f"   3. peserta_not_approved_ditemukan.csv")
print(f"      → NOT APPROVED yang ditemukan di Certiport ({len(found_df)} peserta)")
print(f"   4. peserta_not_approved_tidak_ditemukan.csv")
print(f"      → NOT APPROVED yang TIDAK ditemukan di Certiport ({len(not_found_all_df)} peserta)")
print(f"\n{'=' * 70}")
# Out:
# ======================================================================
# EXPORT HASIL KE FILE CSV
# ======================================================================
# ✅ File hasil telah disimpan:
#
# 📁 PESERTA APPROVED (Langsung Diterima):
#    1. peserta_approved.csv
#       → 85 peserta dengan status APPROVED
#
# 📁 HASIL CROSS-CHECK NOT APPROVED:
#    2. hasil_crosscheck_not_approved.csv
#       → Semua hasil cross-check peserta NOT APPROVED (72 peserta)
#    3. peserta_not_approved_ditemukan.csv
#       → NOT APPROVED yang ditemukan di Certiport (52 peserta)
#    4. peserta_not_approved_tidak_ditemukan.csv
#       → NOT APPROVED yang TIDAK ditemukan di Certiport (20 peserta)
#
# ======================================================================

# %%
# ========== FITUR 1: REKOMENDASI APPROVAL OTOMATIS ==========
print(f"\n{'=' * 70}")
print("⭐ REKOMENDASI PESERTA UNTUK DI-APPROVE")
print(f"=" * 70)

# Peserta yang LAYAK di-approve: NOT APPROVED + TIDAK DITEMUKAN di Certiport (belum pernah ujian)
recommended_for_approval = not_found_all_df.copy()
recommended_for_approval['Rekomendasi'] = '✅ APPROVE - Belum Pernah Ujian'
recommended_for_approval['Alasan'] = 'Peserta belum pernah mengikuti ujian di Certiport'

# Peserta yang TIDAK layak di-approve: NOT APPROVED + SUDAH DITEMUKAN di Certiport (sudah ujian)
not_recommended = found_df.copy()
not_recommended['Rekomendasi'] = '❌ JANGAN APPROVE - Sudah Pernah Ujian'
not_recommended['Alasan'] = 'Peserta sudah pernah ujian (nama ditemukan di database Certiport)'

print(f"✅ REKOMENDASI APPROVE: {len(recommended_for_approval)} peserta")
print(f"   → Peserta ini belum pernah ujian, layak untuk disetujui")
print(f"\n❌ TIDAK DIREKOMENDASIKAN: {len(not_recommended)} peserta")
print(f"   → Peserta ini sudah pernah ujian (ditemukan di Certiport)")

# Breakdown per program
print(f"\n--- Breakdown Rekomendasi per Sumber ---")
print("\n[DIREKOMENDASIKAN untuk APPROVE]:")
if len(recommended_for_approval) > 0:
    print(recommended_for_approval.groupby(['Sumber Data']).size().to_string())
else:
    print("Tidak ada")

print("\n[TIDAK DIREKOMENDASIKAN - sudah ujian]:")
if len(not_recommended) > 0:
    print(not_recommended.groupby(['Sumber Data']).size().to_string())
else:
    print("Tidak ada")

# Tampilkan detail
print(f"\n{'=' * 70}")
print("DETAIL PESERTA YANG DIREKOMENDASIKAN UNTUK APPROVE")
print(f"=" * 70)
if len(recommended_for_approval) > 0:
    print(recommended_for_approval[['Nama Peserta', 'NIM', 'Sumber Data', 'Program', 'Rekomendasi']].to_string(index=False))
else:
    print("Tidak ada peserta yang direkomendasikan untuk di-approve")

# Export rekomendasi
recommended_for_approval.to_csv('APPROVE_INI_belum_pernah_ujian.csv', index=False, encoding='utf-8-sig')
not_recommended.to_csv('JANGAN_APPROVE_sudah_ujian.csv', index=False, encoding='utf-8-sig')

print(f"\n{'=' * 70}")
print("✅ File rekomendasi telah disimpan:")
print(f"   📄 APPROVE_INI_belum_pernah_ujian.csv")
print(f"      → {len(recommended_for_approval)} peserta yang LAYAK DI-APPROVE")
print(f"   📄 JANGAN_APPROVE_sudah_ujian.csv")
print(f"      → {len(not_recommended)} peserta yang JANGAN DI-APPROVE (sudah ujian)")
print(f"=" * 70)
# Out:
# ======================================================================
# ⭐ REKOMENDASI PESERTA UNTUK DI-APPROVE
# ======================================================================
# ✅ REKOMENDASI APPROVE: 20 peserta
#    → Peserta ini belum pernah ujian, layak untuk disetujui
#
# ❌ TIDAK DIREKOMENDASIKAN: 52 peserta
#    → Peserta ini sudah pernah ujian (ditemukan di Certiport)
#
# --- Breakdown Rekomendasi per Sumber ---
#
# [DIREKOMENDASIKAN untuk APPROVE]:
# Sumber Data
# MCF    10
# MOS    10
#
# [TIDAK DIREKOMENDASIKAN - sudah ujian]:
# Sumber Data
# MCF     3
# MOS    49
#
# ======================================================================
# DETAIL PESERTA YANG DIREKOMENDASIKAN UNTUK APPROVE
# ======================================================================
#                         Nama Peserta       NIM Sumber Data           Program                    Rekomendasi
#                   HABIL RAMA TAUFANY 202231077         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                    LUTFIANSYAH MAJID 202131129         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                 KASHRINA MASYID AZKA 202231055         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                MUHAMMAD NAUFAL ARIEF 202231026         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#       DESTA AZRA ROSANI FEERLIAN ADI 202232033         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                     POPY LEONI PURBA 202231079         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
# SERLINA MARGARET BANOET BR HUTAHAEAN 202131161         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                         DEWI SAFITRI 202231011         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                       GRACE HUTASOIT 202231082         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#                 AFFANDI MUFTI NASRUN 201831201         MCF MCF: Azure AI-900 ✅ APPROVE - Belum Pernah Ujian
#            MUHAMMAD ALLIF HABIBILLAH 202242014         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#                       CARLOS LIMBONG 202112036         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#                      NADYARA NATASHA 202232009         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#                  IBNU RASYID AL FAIZ 202232028         MOS        MOS: Excel ✅ APPROVE - Belum Pernah Ujian
#                   SEPTIAN DWI ANDANA 202214009         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#          LORENZO GONZALEZ SITUMORANG 201931071         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#                   MICKY IKHSAN ASRIL 201911059         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#               ANDI XAVIER WIDYADHANA 202231052         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#                         DHIAZ ADITYA 202212040         MOS         MOS: Word ✅ APPROVE - Belum Pernah Ujian
#     MUHAMMAD VIRGIAWAN PUTRA KARMAJI 202232034         MOS        MOS: Excel ✅ APPROVE - Belum Pernah Ujian
#
# ======================================================================
# ✅ File rekomendasi telah disimpan:
#    📄 APPROVE_INI_belum_pernah_ujian.csv
#       → 20 peserta yang LAYAK DI-APPROVE
#    📄 JANGAN_APPROVE_sudah_ujian.csv
#       → 52 peserta yang JANGAN DI-APPROVE (sudah ujian)
# ======================================================================

# %%
# ========== FITUR 2: DETEKSI PESERTA YANG PERNAH GAGAL ==========
print(f"\n{'=' * 70}")
print("⚠️  DETEKSI PESERTA YANG PERNAH GAGAL UJIAN")
print(f"=" * 70)

# Gabungkan data MCF dan MOS Certiport
all_certiport = pd.concat([certiport_mcf, certiport_mos], ignore_index=True)

# Filter peserta yang pernah gagal
if 'Result' in all_certiport.columns:
    failed_students = all_certiport[all_certiport['Result'] == 'Fail'].copy()
    
    print(f"Total peserta yang pernah GAGAL di Certiport: {len(failed_students)}")
    
    if len(failed_students) > 0:
        # Buat Full Name Normalized untuk failed students
        failed_students['Full Name Normalized'] = failed_students.apply(
            lambda x: normalize_name(f"{x['First Name']} {x['Last Name']}"), axis=1
        )
        
        # Tambahkan kolom Nama Normalized ke not_approved_df
        not_approved_df_temp = not_approved_df.copy()
        not_approved_df_temp['Nama Normalized'] = not_approved_df_temp['Nama'].apply(normalize_name)
        
        # Cari yang pernah gagal dan daftar lagi
        daftar_lagi = []
        for idx, row in not_approved_df_temp.iterrows():
            nama_normalized = row['Nama Normalized']
            sumber = row['Sumber']
            
            # Filter berdasarkan sumber (MCF cek MCF, MOS cek MOS)
            if sumber == 'MCF':
                failed_to_check = failed_students[failed_students['Exam'].str.contains('AI-900', na=False)]
            else:
                failed_to_check = failed_students[failed_students['Exam'].str.contains('Office 2019', na=False)]
            
            # Cek kecocokan dengan fuzzy matching
            for _, failed_row in failed_to_check.iterrows():
                failed_name = failed_row['Full Name Normalized']
                # Cek exact match atau fuzzy match tinggi
                score = fuzz.token_set_ratio(nama_normalized, failed_name)
                if score >= 85 or nama_normalized == failed_name:
                    daftar_lagi.append({
                        'Nama Peserta': row['Nama'],
                        'NIM': row['NIM'],
                        'Sumber Data': sumber,
                        'Program Daftar': row['Program Dipilih'],
                        'Status': '⚠️ PERNAH GAGAL - DAFTAR LAGI',
                        'Nama di Certiport': f"{failed_row['First Name']} {failed_row['Last Name']}",
                        'Exam Sebelumnya': failed_row['Exam'],
                        'Tanggal Ujian': failed_row['Exam Date'] if 'Exam Date' in failed_row else '-',
                        'Skor Sebelumnya': failed_row['Score'] if 'Score' in failed_row else '-',
                        'Skor Kecocokan Nama': score,
                        'Keputusan': '❓ PERLU REVIEW MANUAL'
                    })
                    break  # Hanya ambil 1 match per peserta
        
        if len(daftar_lagi) > 0:
            daftar_lagi_df = pd.DataFrame(daftar_lagi)
            print(f"\n⚠️  PERHATIAN: {len(daftar_lagi_df)} peserta PERNAH GAGAL dan DAFTAR LAGI!")
            print(f"\n--- Detail Peserta yang Pernah Gagal ---")
            print(daftar_lagi_df[['Nama Peserta', 'NIM', 'Sumber Data', 'Exam Sebelumnya', 'Skor Sebelumnya', 'Keputusan']].to_string(index=False))
            
            daftar_lagi_df.to_csv('PERHATIAN_peserta_gagal_daftar_lagi.csv', index=False, encoding='utf-8-sig')
            print(f"\n📄 File PERHATIAN_peserta_gagal_daftar_lagi.csv telah disimpan")
            print(f"\n💡 SARAN: Review manual diperlukan untuk peserta ini.")
            print(f"   Pertimbangkan: apakah boleh mengikuti ujian lagi?")
        else:
            print("\n✅ Tidak ada peserta NOT APPROVED yang pernah gagal ujian sebelumnya")
            daftar_lagi_df = pd.DataFrame()  # Empty dataframe
    else:
        print("\n✅ Tidak ada data peserta yang gagal di Certiport")
        daftar_lagi_df = pd.DataFrame()
else:
    print("\n⚠️  Kolom 'Result' tidak ditemukan di data Certiport")
    daftar_lagi_df = pd.DataFrame()
# Out:
# ======================================================================
# ⚠️  DETEKSI PESERTA YANG PERNAH GAGAL UJIAN
# ======================================================================
# Total peserta yang pernah GAGAL di Certiport: 1714
#
# ⚠️  PERHATIAN: 44 peserta PERNAH GAGAL dan DAFTAR LAGI!
#
# --- Detail Peserta yang Pernah Gagal ---
#                       Nama Peserta       NIM Sumber Data                    Exam Sebelumnya  Skor Sebelumnya             Keputusan
#               RAIHAN CANDRA IRAWAN 202211117         MOS       Microsoft Word (Office 2019)            668.0 ❓ PERLU REVIEW MANUAL
#                    MUHAMMAD RAIHAN 202241017         MOS       Microsoft Word (Office 2019)            636.0 ❓ PERLU REVIEW MANUAL
# MUHAMMAD REVIANSYAH DANENDRA PUTRA 202131160         MOS       Microsoft Word (Office 2019)            152.0 ❓ PERLU REVIEW MANUAL
#    DHEA HERAWATI INDAH PUTRI ERWIN 202231088         MOS       Microsoft Word (Office 2019)            127.0 ❓ PERLU REVIEW MANUAL
#                BINTAR ANDIKA PUTRA 202211113         MOS Microsoft PowerPoint (Office 2019)            547.0 ❓ PERLU REVIEW MANUAL
#           RACHMAD FAQIH AFGIANSYAH 202112050         MOS       Microsoft Word (Office 2019)            426.0 ❓ PERLU REVIEW MANUAL
#                      JIHAN DIOVANT 202212037         MOS       Microsoft Word (Office 2019)            578.0 ❓ PERLU REVIEW MANUAL
#                NADELLA EZI SABRINA 202232010         MOS      Microsoft Excel (Office 2019)            147.0 ❓ PERLU REVIEW MANUAL
#             JOHN ANDREW TAMPUBOLON 202211153         MOS       Microsoft Word (Office 2019)            477.0 ❓ PERLU REVIEW MANUAL
#           SARIFA ARINI LATUCONSINA 202231041         MOS Microsoft PowerPoint (Office 2019)            152.0 ❓ PERLU REVIEW MANUAL
#                   AHMAD TRI STIADI 202211101         MOS      Microsoft Excel (Office 2019)            294.0 ❓ PERLU REVIEW MANUAL
#                  DAVID AJI PRAYOGA 202211050         MOS       Microsoft Word (Office 2019)            395.0 ❓ PERLU REVIEW MANUAL
#            TARISA DWINA ARTHANEVIA 202232022         MOS       Microsoft Word (Office 2019)            365.0 ❓ PERLU REVIEW MANUAL
#       MUHAMMAD RIZKY BAMBY SAPUTRA 202232002         MOS       Microsoft Word (Office 2019)            608.0 ❓ PERLU REVIEW MANUAL
#            ARIO YOGATAMA ERLAPUTRA 202242012         MOS       Microsoft Word (Office 2019)            254.0 ❓ PERLU REVIEW MANUAL
#                      SANDIKA NAMBO 202011201         MOS       Microsoft Word (Office 2019)            334.0 ❓ PERLU REVIEW MANUAL
#               BAIQ PUTRI SUARTIKHA 202232023         MOS      Microsoft Excel (Office 2019)            273.0 ❓ PERLU REVIEW MANUAL
#              JUAN GERALD ARITONANG 202232007         MOS       Microsoft Word (Office 2019)            286.0 ❓ PERLU REVIEW MANUAL
#                INAYAH ANANDA PUTRI 202221011         MOS      Microsoft Excel (Office 2019)            578.0 ❓ PERLU REVIEW MANUAL
#     I GEDE PUTU BAGUS KRISNA PANDE 202231042         MOS      Microsoft Excel (Office 2019)            456.0 ❓ PERLU REVIEW MANUAL
#          KOMANG ARYA DIVA PRAMARTA 202211008         MOS      Microsoft Excel (Office 2019)            426.0 ❓ PERLU REVIEW MANUAL
#       I MADE DWI MAHA PUTRA SUJANA 202211012         MOS      Microsoft Excel (Office 2019)            426.0 ❓ PERLU REVIEW MANUAL
#              WAHID YAMINSYAH PUTRA 202231040         MOS       Microsoft Word (Office 2019)             95.0 ❓ PERLU REVIEW MANUAL
#                    GALIH RAKA SIWI 202231060         MOS       Microsoft Word (Office 2019)            445.0 ❓ PERLU REVIEW MANUAL
#               AKMAL DZAKY ADHYNATA 202212031         MOS      Microsoft Excel (Office 2019)            608.0 ❓ PERLU REVIEW MANUAL
#           DWIANTORO AZKA NAYOTTAMA 202212039         MOS       Microsoft Word (Office 2019)            243.0 ❓ PERLU REVIEW MANUAL
#           SYAIFULLAH YUSUF SAPUTRA 202212523         MOS       Microsoft Word (Office 2019)            636.0 ❓ PERLU REVIEW MANUAL
#           SARAH AISYAH KUSUMAHARJO 202211086         MOS      Microsoft Excel (Office 2019)            365.0 ❓ PERLU REVIEW MANUAL
#                   ZAKI RIZALUL HAQ 202214007         MOS Microsoft PowerPoint (Office 2019)            112.0 ❓ PERLU REVIEW MANUAL
#                     RIZKY RAMADHAN 202212038         MOS       Microsoft Word (Office 2019)             31.0 ❓ PERLU REVIEW MANUAL
#                  DANI ABID ASSINDI 202211079         MOS      Microsoft Excel (Office 2019)            331.0 ❓ PERLU REVIEW MANUAL
#            MUHAMMAD NOFRAN SAPUTRA 202211082         MOS       Microsoft Word (Office 2019)            608.0 ❓ PERLU REVIEW MANUAL
#               AZHAR LAZUARDI IMANI 202211136         MOS      Microsoft Excel (Office 2019)            147.0 ❓ PERLU REVIEW MANUAL
#        ROVAN LUWID ERVAN SIHOMBING 202212002         MOS      Microsoft Excel (Office 2019)            426.0 ❓ PERLU REVIEW MANUAL
#                 HABIL RAMA TAUFANY 202231077         MOS       Microsoft Word (Office 2019)            477.0 ❓ PERLU REVIEW MANUAL
#              MUHAMMAD NAUFAL ARIEF 202231026         MOS      Microsoft Excel (Office 2019)            257.0 ❓ PERLU REVIEW MANUAL
#                       AZRA OKSYANI 202212012         MOS       Microsoft Word (Office 2019)            304.0 ❓ PERLU REVIEW MANUAL
#              MUHAMMAD RAFI PRATAMA 202211141         MOS       Microsoft Word (Office 2019)            604.0 ❓ PERLU REVIEW MANUAL
#               ZAGHI PRIMA MANGGALA 202242006         MOS       Microsoft Word (Office 2019)            152.0 ❓ PERLU REVIEW MANUAL
#                   M RIZKY RAMADHAN 202231065         MOS       Microsoft Word (Office 2019)             31.0 ❓ PERLU REVIEW MANUAL
#                      MUHAMMAD RAFI 202231036         MOS       Microsoft Word (Office 2019)            639.0 ❓ PERLU REVIEW MANUAL
#                 RISHA FIRLY APSARI 202242022         MOS       Microsoft Word (Office 2019)            365.0 ❓ PERLU REVIEW MANUAL
#                   LASMA DEVI ARUAN 202111143         MOS      Microsoft Excel (Office 2019)            552.0 ❓ PERLU REVIEW MANUAL
#                  SURYA ADI SAPUTRA 202111150         MOS      Microsoft Excel (Office 2019)            405.0 ❓ PERLU REVIEW MANUAL
#
# 📄 File PERHATIAN_peserta_gagal_daftar_lagi.csv telah disimpan
#
# 💡 SARAN: Review manual diperlukan untuk peserta ini.
#    Pertimbangkan: apakah boleh mengikuti ujian lagi?

# %%
# ========== FITUR 3: DASHBOARD SUMMARY ==========
print(f"\n{'=' * 100}")
print(" " * 35 + "📊 DASHBOARD SUMMARY")
print(f"=" * 100)

total_peserta = len(peserta_df)
total_not_approved = len(not_approved_df)

# Buat tabel summary
print(f"""
┌─────────────────────────────────────────────────────────────────────────────────┐
│                              DATA PENDAFTAR                                      │
├─────────────────────────────────────────────────────────────────────────────────┤
│  Total Pendaftar              : {total_peserta:>5} peserta                                  │
│    ├─ MCF (Azure AI-900)      : {len(peserta_mcf_df):>5} peserta ({len(peserta_mcf_df)/total_peserta*100:>5.1f}%)                       │
│    └─ MOS (Office 2019)       : {len(peserta_mos_df):>5} peserta ({len(peserta_mos_df)/total_peserta*100:>5.1f}%)                       │
├─────────────────────────────────────────────────────────────────────────────────┤
│                            STATUS REGISTRASI                                     │
├─────────────────────────────────────────────────────────────────────────────────┤
│  ✅ Status APPROVED           : {len(approved_df):>5} peserta ({len(approved_df)/total_peserta*100:>5.1f}%)                       │
│  ⏳ Status NOT APPROVED       : {len(not_approved_df):>5} peserta ({len(not_approved_df)/total_peserta*100:>5.1f}%)                       │
├─────────────────────────────────────────────────────────────────────────────────┤
│                           DATA CERTIPORT                                         │
├─────────────────────────────────────────────────────────────────────────────────┤
│  Total Data Certiport         : {len(certiport_df):>5} records                                  │
│    ├─ MCF (AI-900)            : {len(certiport_mcf):>5} records                                  │
│    └─ MOS (Office 2019)       : {len(certiport_mos):>5} records                                  │
├─────────────────────────────────────────────────────────────────────────────────┤
│                      HASIL CROSS-CHECK (NOT APPROVED)                            │
├─────────────────────────────────────────────────────────────────────────────────┤
│  ✅ Ditemukan di Certiport    : {len(found_df):>5} peserta ({len(found_df)/total_not_approved*100 if total_not_approved > 0 else 0:>5.1f}%)  → JANGAN APPROVE    │
│  ❌ Tidak ditemukan           : {len(not_found_all_df):>5} peserta ({len(not_found_all_df)/total_not_approved*100 if total_not_approved > 0 else 0:>5.1f}%)  → APPROVE INI       │
├─────────────────────────────────────────────────────────────────────────────────┤
│  ⚠️  Pernah Gagal Daftar Lagi : {len(daftar_lagi_df) if 'daftar_lagi_df' in dir() else 0:>5} peserta          → PERLU REVIEW      │
└─────────────────────────────────────────────────────────────────────────────────┘
""")

print(f"\n{'=' * 100}")
print("🎯 REKOMENDASI AKHIR:")
print(f"   ✅ APPROVE {len(recommended_for_approval)} peserta (belum pernah ujian)")
print(f"   ❌ JANGAN APPROVE {len(not_recommended)} peserta (sudah pernah ujian)")
if 'daftar_lagi_df' in dir() and len(daftar_lagi_df) > 0:
    print(f"   ⚠️  REVIEW MANUAL {len(daftar_lagi_df)} peserta (pernah gagal, daftar lagi)")
print(f"=" * 100)
# Out:
# ====================================================================================================
#                                    📊 DASHBOARD SUMMARY
# ====================================================================================================
#
# ┌─────────────────────────────────────────────────────────────────────────────────┐
# │                              DATA PENDAFTAR                                      │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │  Total Pendaftar              :   157 peserta                                  │
# │    ├─ MCF (Azure AI-900)      :    56 peserta ( 35.7%)                       │
# │    └─ MOS (Office 2019)       :   101 peserta ( 64.3%)                       │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │                            STATUS REGISTRASI                                     │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │  ✅ Status APPROVED           :    85 peserta ( 54.1%)                       │
# │  ⏳ Status NOT APPROVED       :    72 peserta ( 45.9%)                       │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │                           DATA CERTIPORT                                         │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │  Total Data Certiport         :  4853 records                                  │
# │    ├─ MCF (AI-900)            :   897 records                                  │
# │    └─ MOS (Office 2019)       :  3445 records                                  │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │                      HASIL CROSS-CHECK (NOT APPROVED)                            │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │  ✅ Ditemukan di Certiport    :    52 peserta ( 72.2%)  → JANGAN APPROVE    │
# │  ❌ Tidak ditemukan           :    20 peserta ( 27.8%)  → APPROVE INI       │
# ├─────────────────────────────────────────────────────────────────────────────────┤
# │  ⚠️  Pernah Gagal Daftar Lagi :    44 peserta          → PERLU REVIEW      │
# └─────────────────────────────────────────────────────────────────────────────────┘
#
#
# ====================================================================================================
# 🎯 REKOMENDASI AKHIR:
#    ✅ APPROVE 20 peserta (belum pernah ujian)
#    ❌ JANGAN APPROVE 52 peserta (sudah pernah ujian)
#    ⚠️  REVIEW MANUAL 44 peserta (pernah gagal, daftar lagi)
# ====================================================================================================

# %%
# ========== FITUR 4: FILTER LANJUTAN BERDASARKAN CONFIDENCE ==========
print(f"\n{'=' * 70}")
print("🔍 FILTER LANJUTAN - ANALISIS TINGKAT KEPERCAYAAN MATCHING")
print(f"=" * 70)

# Kategorisasi berdasarkan skor kecocokan
def kategorisasi_confidence(row):
    score = row['Skor Kecocokan']
    tipe = row['Tipe Match']
    
    if tipe == 'Exact Match' or tipe == 'Exact Match (Nama Terbalik)':
        return 'HIGH - Exact Match'
    elif score >= 95:
        return 'HIGH - Sangat Yakin'
    elif score >= 85:
        return 'MEDIUM - Cukup Yakin'
    elif score >= 80:
        return 'LOW - Perlu Verifikasi'
    else:
        return 'NOT MATCHED'

# Terapkan kategorisasi ke data yang ditemukan
if len(found_df) > 0:
    found_df['Confidence Level'] = found_df.apply(kategorisasi_confidence, axis=1)
    
    print("\n📊 BREAKDOWN TINGKAT KEPERCAYAAN MATCHING:")
    print(found_df['Confidence Level'].value_counts().to_string())
    
    # Filter berdasarkan confidence
    high_confidence = found_df[found_df['Confidence Level'].str.contains('HIGH')]
    medium_confidence = found_df[found_df['Confidence Level'] == 'MEDIUM - Cukup Yakin']
    low_confidence = found_df[found_df['Confidence Level'] == 'LOW - Perlu Verifikasi']
    
    print(f"\n--- HIGH CONFIDENCE ({len(high_confidence)} peserta) ---")
    print("→ Nama cocok dengan sangat akurat, YAKIN sudah pernah ujian")
    if len(high_confidence) > 0:
        print(high_confidence[['Nama Peserta', 'Nama di Certiport', 'Skor Kecocokan', 'Confidence Level']].to_string(index=False))
    
    print(f"\n--- MEDIUM CONFIDENCE ({len(medium_confidence)} peserta) ---")
    print("→ Nama cukup cocok, kemungkinan besar sudah pernah ujian")
    if len(medium_confidence) > 0:
        print(medium_confidence[['Nama Peserta', 'Nama di Certiport', 'Skor Kecocokan', 'Confidence Level']].to_string(index=False))
    
    print(f"\n--- LOW CONFIDENCE ({len(low_confidence)} peserta) ---")
    print("→ ⚠️ PERLU VERIFIKASI MANUAL - Nama mirip tapi tidak yakin 100%")
    if len(low_confidence) > 0:
        print(low_confidence[['Nama Peserta', 'Nama di Certiport', 'Skor Kecocokan', 'Confidence Level']].to_string(index=False))
    
    # Deteksi kemungkinan false positive (nama yang mungkin salah match)
    print(f"\n{'=' * 70}")
    print("⚠️  DETEKSI KEMUNGKINAN FALSE POSITIVE (SALAH MATCHING)")
    print(f"=" * 70)
    
    suspicious_matches = found_df[
        (found_df['Skor Kecocokan'] < 90) | 
        (found_df['Confidence Level'] == 'LOW - Perlu Verifikasi')
    ].copy()
    
    if len(suspicious_matches) > 0:
        print(f"Ditemukan {len(suspicious_matches)} peserta yang PERLU DICEK ULANG:")
        print("(Kemungkinan nama yang cocok adalah orang berbeda)")
        print()
        for idx, row in suspicious_matches.iterrows():
            print(f"  ❓ {row['Nama Peserta']}")
            print(f"     → Cocok dengan: {row['Nama di Certiport']}")
            print(f"     → Skor: {row['Skor Kecocokan']} | {row['Confidence Level']}")
            print()
        
        suspicious_matches.to_csv('VERIFIKASI_matching_meragukan.csv', index=False, encoding='utf-8-sig')
        print(f"📄 File VERIFIKASI_matching_meragukan.csv telah disimpan")
    else:
        print("✅ Semua matching memiliki tingkat kepercayaan tinggi")
else:
    print("✅ Tidak ada peserta yang ditemukan di Certiport (semua baru)")

# Update found_df untuk export
if len(found_df) > 0:
    found_df.to_csv('JANGAN_APPROVE_sudah_ujian.csv', index=False, encoding='utf-8-sig')
# Out:
# ======================================================================
# 🔍 FILTER LANJUTAN - ANALISIS TINGKAT KEPERCAYAAN MATCHING
# ======================================================================
#
# 📊 BREAKDOWN TINGKAT KEPERCAYAAN MATCHING:
# Confidence Level
# HIGH - Sangat Yakin       37
# HIGH - Exact Match        11
# MEDIUM - Cukup Yakin       2
# LOW - Perlu Verifikasi     2
#
# --- HIGH CONFIDENCE (48 peserta) ---
# → Nama cocok dengan sangat akurat, YAKIN sudah pernah ujian
#                       Nama Peserta                  Nama di Certiport  Skor Kecocokan    Confidence Level
#          MUHAMMAD RIFQI APRIANSYAH                     MUHAMMAD RIFQI             100 HIGH - Sangat Yakin
#               RAIHAN CANDRA IRAWAN                      RAIHAN IRAWAN             100 HIGH - Sangat Yakin
#                    MUHAMMAD RAIHAN                    MUHAMMAD RAIHAN             100  HIGH - Exact Match
# MUHAMMAD REVIANSYAH DANENDRA PUTRA MUHAMMAD REVIANSYAH DANENDRA PUTRA             100  HIGH - Exact Match
#    DHEA HERAWATI INDAH PUTRI ERWIN          DHEA HERAWATI PUTRI ERWIN             100 HIGH - Sangat Yakin
#          ANDI MUHAMMAD NABIL ALKAF                     MUHAMMAD NABIL             100 HIGH - Sangat Yakin
#                BINTAR ANDIKA PUTRA                       BINTAR PUTRA             100 HIGH - Sangat Yakin
#           RACHMAD FAQIH AFGIANSYAH           RACHMAD FAQIH AFGIANSYAH             100  HIGH - Exact Match
#                      JIHAN DIOVANT              JIHAN AZZAHRA DIOVANT             100 HIGH - Sangat Yakin
#                NADELLA EZI SABRINA                    NADELLA SABRINA             100 HIGH - Sangat Yakin
#             JOHN ANDREW TAMPUBOLON             JOHN ANDREW TAMPUBOLON             100  HIGH - Exact Match
#           SARIFA ARINI LATUCONSINA                 SARIFA LATUCONSINA             100 HIGH - Sangat Yakin
#                   AHMAD TRI STIADI                       AHMAD STIADI             100 HIGH - Sangat Yakin
#                  DAVID AJI PRAYOGA                      DAVID PRAYOGA             100 HIGH - Sangat Yakin
#            TARISA DWINA ARTHANEVIA                  TARISA ARTHANEVIA             100 HIGH - Sangat Yakin
#       MUHAMMAD RIZKY BAMBY SAPUTRA             MUHAMMAD RIZKY SAPUTRA             100 HIGH - Sangat Yakin
#            ARIO YOGATAMA ERLAPUTRA                     ARIO ERLAPUTRA             100 HIGH - Sangat Yakin
#                      SANDIKA NAMBO                SANDIKA LAODE NAMBO             100 HIGH - Sangat Yakin
#               BAIQ PUTRI SUARTIKHA                     BAIQ SUARTIKHA             100 HIGH - Sangat Yakin
#              JUAN GERALD ARITONANG                     JUAN ARITONANG             100 HIGH - Sangat Yakin
#                    DIMAS DAMARJATI                    DIMAS DAMARJATI             100  HIGH - Exact Match
#                INAYAH ANANDA PUTRI                       INAYAH PUTRI             100 HIGH - Sangat Yakin
#     I GEDE PUTU BAGUS KRISNA PANDE                  I GEDE PUTU PANDE             100 HIGH - Sangat Yakin
#          KOMANG ARYA DIVA PRAMARTA                        KOMANG ARYA             100 HIGH - Sangat Yakin
#       I MADE DWI MAHA PUTRA SUJANA                      I MADE SUJANA             100 HIGH - Sangat Yakin
#              WAHID YAMINSYAH PUTRA                        WAHID PUTRA             100 HIGH - Sangat Yakin
#                    GALIH RAKA SIWI                         GALIH SIWI             100 HIGH - Sangat Yakin
#               AKMAL DZAKY ADHYNATA                     AKMAL ADHYNATA             100 HIGH - Sangat Yakin
#           DWIANTORO AZKA NAYOTTAMA                DWIANTORO NAYOTTAMA             100 HIGH - Sangat Yakin
#           SYAIFULLAH YUSUF SAPUTRA           SYAIFULLAH YUSUF SAPUTRA             100  HIGH - Exact Match
#           SARAH AISYAH KUSUMAHARJO                  SARAH KUSUMAHARJO             100 HIGH - Sangat Yakin
#             MUHAMMAD SADDAM WIJAYA                    MUHAMMAD WIJAYA             100 HIGH - Sangat Yakin
#                   ZAKI RIZALUL HAQ                   ZAKI RIZALUL HAQ             100  HIGH - Exact Match
#                     RIZKY RAMADHAN                     RIZKY RAMADHAN             100  HIGH - Exact Match
#                  DANI ABID ASSINDI                       DANI ASSINDI             100 HIGH - Sangat Yakin
#            MUHAMMAD NOFRAN SAPUTRA                   MUHAMMAD SAPUTRA             100 HIGH - Sangat Yakin
#               AZHAR LAZUARDI IMANI                        AZHAR IMANI             100 HIGH - Sangat Yakin
#        ROVAN LUWID ERVAN SIHOMBING                    ROVAN SIHOMBING             100 HIGH - Sangat Yakin
#                 HABIL RAMA TAUFANY                      HABIL TAUFANY             100 HIGH - Sangat Yakin
#              MUHAMMAD NAUFAL ARIEF              MUHAMMAD NAUFAL ARIEF             100  HIGH - Exact Match
#                       AZRA OKSYANI                       AZRA OKSYANI             100  HIGH - Exact Match
#              MUHAMMAD RAFI PRATAMA                   MUHAMMAD PRATAMA             100 HIGH - Sangat Yakin
#               ZAGHI PRIMA MANGGALA                     ZAGHI MANGGALA             100 HIGH - Sangat Yakin
#                   M RIZKY RAMADHAN                     RIZKY RAMADHAN             100 HIGH - Sangat Yakin
#                      MUHAMMAD RAFI               MUHAMMAD RAFI FARHAN             100 HIGH - Sangat Yakin
#                 RISHA FIRLY APSARI                       RISHA APSARI             100 HIGH - Sangat Yakin
#                   LASMA DEVI ARUAN                        LASMA ARUAN             100 HIGH - Sangat Yakin
#                  SURYA ADI SAPUTRA                  SURYA ADI SAPUTRA             100  HIGH - Exact Match
#
# --- MEDIUM CONFIDENCE (2 peserta) ---
# → Nama cukup cocok, kemungkinan besar sudah pernah ujian
#            Nama Peserta    Nama di Certiport  Skor Kecocokan     Confidence Level
# MUHAMMAD RAFI AL ANBIYA MUHAMMAD RAFI FARHAN              85 MEDIUM - Cukup Yakin
#    UMMU PUTRI SALSABILA  SALSABILA EKA PUTRI              88 MEDIUM - Cukup Yakin
#
# --- LOW CONFIDENCE (2 peserta) ---
# → ⚠️ PERLU VERIFIKASI MANUAL - Nama mirip tapi tidak yakin 100%
#              Nama Peserta    Nama di Certiport  Skor Kecocokan       Confidence Level
# RADEN MUHAMMAD ASYAM RAFI MUHAMMAD RAFI FARHAN              80 LOW - Perlu Verifikasi
#    MUHAMMAD DAFFA ZHAFRAN MUHAMMAD DAFFA JOWIS              82 LOW - Perlu Verifikasi
#
# ======================================================================
# ⚠️  DETEKSI KEMUNGKINAN FALSE POSITIVE (SALAH MATCHING)
# ======================================================================
# Ditemukan 4 peserta yang PERLU DICEK ULANG:
# (Kemungkinan nama yang cocok adalah orang berbeda)
#
#   ❓ MUHAMMAD RAFI AL ANBIYA
#      → Cocok dengan: MUHAMMAD RAFI FARHAN
#      → Skor: 85 | MEDIUM - Cukup Yakin
#
#   ❓ UMMU PUTRI SALSABILA
#      → Cocok dengan: SALSABILA EKA PUTRI
#      → Skor: 88 | MEDIUM - Cukup Yakin
#
#   ❓ RADEN MUHAMMAD ASYAM RAFI
#      → Cocok dengan: MUHAMMAD RAFI FARHAN
#      → Skor: 80 | LOW - Perlu Verifikasi
#
#   ❓ MUHAMMAD DAFFA ZHAFRAN
#      → Cocok dengan: MUHAMMAD DAFFA JOWIS
#      → Skor: 82 | LOW - Perlu Verifikasi
#
# 📄 File VERIFIKASI_matching_meragukan.csv telah disimpan

# %%
# ========== FITUR 5: EXPORT KE EXCEL DENGAN MULTIPLE SHEETS ==========
print(f"\n{'=' * 70}")
print("📊 EXPORT KE EXCEL DENGAN MULTIPLE SHEETS & HIGHLIGHTING")
print(f"=" * 70)

# Install openpyxl jika belum ada
try:
    from openpyxl import Workbook
    from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
    from openpyxl.utils.dataframe import dataframe_to_rows
    print("✅ Library openpyxl tersedia")
except ImportError:
    print("⚠️ Installing openpyxl...")
    import subprocess
    subprocess.check_call(['pip', 'install', 'openpyxl'])
    from openpyxl import Workbook
    from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
    from openpyxl.utils.dataframe import dataframe_to_rows
    print("✅ Library openpyxl berhasil diinstall")

# Buat workbook baru
wb = Workbook()

# Style definitions
header_fill = PatternFill(start_color="1F4E79", end_color="1F4E79", fill_type="solid")
header_font = Font(color="FFFFFF", bold=True)
approve_fill = PatternFill(start_color="C6EFCE", end_color="C6EFCE", fill_type="solid")  # Hijau muda
reject_fill = PatternFill(start_color="FFC7CE", end_color="FFC7CE", fill_type="solid")    # Merah muda
warning_fill = PatternFill(start_color="FFEB9C", end_color="FFEB9C", fill_type="solid")   # Kuning muda
thin_border = Border(
    left=Side(style='thin'), right=Side(style='thin'),
    top=Side(style='thin'), bottom=Side(style='thin')
)

def style_worksheet(ws, df, highlight_col=None, approve_value=None, reject_value=None):
    """Apply styling to worksheet"""
    # Header styling
    for cell in ws[1]:
        cell.fill = header_fill
        cell.font = header_font
        cell.alignment = Alignment(horizontal='center', vertical='center')
        cell.border = thin_border
    
    # Data styling
    for row_idx, row in enumerate(ws.iter_rows(min_row=2, max_row=ws.max_row, min_col=1, max_col=ws.max_column), start=2):
        for cell in row:
            cell.border = thin_border
            cell.alignment = Alignment(vertical='center')
        
        # Highlight berdasarkan kolom tertentu
        if highlight_col and highlight_col <= len(row):
            cell_value = str(ws.cell(row=row_idx, column=highlight_col).value)
            if approve_value and approve_value in cell_value:
                for cell in row:
                    cell.fill = approve_fill
            elif reject_value and reject_value in cell_value:
                for cell in row:
                    cell.fill = reject_fill
            elif '⚠️' in cell_value or 'REVIEW' in cell_value or 'LOW' in cell_value:
                for cell in row:
                    cell.fill = warning_fill
    
    # Auto-adjust column width
    for column in ws.columns:
        max_length = 0
        column_letter = column[0].column_letter
        for cell in column:
            try:
                if len(str(cell.value)) > max_length:
                    max_length = len(str(cell.value))
            except:
                pass
        adjusted_width = min(max_length + 2, 50)
        ws.column_dimensions[column_letter].width = adjusted_width

# Sheet 1: Dashboard Summary
ws1 = wb.active
ws1.title = "Dashboard Summary"
summary_data = [
    ["KATEGORI", "JUMLAH", "PERSENTASE", "STATUS"],
    ["Total Pendaftar", len(peserta_df), "100%", "ℹ️"],
    ["  ├─ MCF (Azure AI-900)", len(peserta_mcf_df), f"{len(peserta_mcf_df)/len(peserta_df)*100:.1f}%", ""],
    ["  └─ MOS (Office 2019)", len(peserta_mos_df), f"{len(peserta_mos_df)/len(peserta_df)*100:.1f}%", ""],
    ["", "", "", ""],
    ["Status APPROVED", len(approved_df), f"{len(approved_df)/len(peserta_df)*100:.1f}%", "✅"],
    ["Status NOT APPROVED", len(not_approved_df), f"{len(not_approved_df)/len(peserta_df)*100:.1f}%", "⏳"],
    ["", "", "", ""],
    ["NOT APPROVED - Sudah Ujian", len(found_df), f"{len(found_df)/len(not_approved_df)*100:.1f}%" if len(not_approved_df) > 0 else "0%", "❌ JANGAN APPROVE"],
    ["NOT APPROVED - Belum Ujian", len(not_found_all_df), f"{len(not_found_all_df)/len(not_approved_df)*100:.1f}%" if len(not_approved_df) > 0 else "0%", "✅ APPROVE INI"],
]
for row in summary_data:
    ws1.append(row)
style_worksheet(ws1, None, highlight_col=4, approve_value="APPROVE INI", reject_value="JANGAN")

# Sheet 2: Rekomendasi APPROVE
ws2 = wb.create_sheet("APPROVE - Belum Ujian")
if len(recommended_for_approval) > 0:
    for r_idx, row in enumerate(dataframe_to_rows(recommended_for_approval[['Nama Peserta', 'NIM', 'Jurusan', 'Sumber Data', 'Program', 'Rekomendasi']], index=False, header=True), 1):
        ws2.append(row)
    style_worksheet(ws2, recommended_for_approval, highlight_col=6, approve_value="APPROVE")
else:
    ws2.append(["Tidak ada peserta yang direkomendasikan untuk approve"])

# Sheet 3: JANGAN APPROVE
ws3 = wb.create_sheet("JANGAN APPROVE - Sudah Ujian")
if len(not_recommended) > 0:
    cols_to_export = ['Nama Peserta', 'NIM', 'Sumber Data', 'Program', 'Nama di Certiport', 'Skor Kecocokan', 'Rekomendasi']
    if 'Confidence Level' in found_df.columns:
        cols_to_export.append('Confidence Level')
    export_df = not_recommended[[c for c in cols_to_export if c in not_recommended.columns]]
    for r_idx, row in enumerate(dataframe_to_rows(export_df, index=False, header=True), 1):
        ws3.append(row)
    style_worksheet(ws3, export_df, highlight_col=7, reject_value="JANGAN")
else:
    ws3.append(["Tidak ada peserta yang sudah pernah ujian"])

# Sheet 4: Perlu Verifikasi (Low Confidence)
ws4 = wb.create_sheet("VERIFIKASI - Low Confidence")
if len(found_df) > 0 and 'Confidence Level' in found_df.columns:
    low_conf = found_df[found_df['Confidence Level'] == 'LOW - Perlu Verifikasi']
    if len(low_conf) > 0:
        for r_idx, row in enumerate(dataframe_to_rows(low_conf[['Nama Peserta', 'NIM', 'Nama di Certiport', 'Skor Kecocokan', 'Confidence Level']], index=False, header=True), 1):
            ws4.append(row)
        style_worksheet(ws4, low_conf)
    else:
        ws4.append(["Tidak ada matching dengan confidence rendah"])
else:
    ws4.append(["Tidak ada data yang perlu diverifikasi"])

# Sheet 5: Peserta Gagal Daftar Lagi
ws5 = wb.create_sheet("REVIEW - Pernah Gagal")
if 'daftar_lagi_df' in dir() and len(daftar_lagi_df) > 0:
    for r_idx, row in enumerate(dataframe_to_rows(daftar_lagi_df, index=False, header=True), 1):
        ws5.append(row)
    style_worksheet(ws5, daftar_lagi_df)
else:
    ws5.append(["Tidak ada peserta yang pernah gagal dan daftar lagi"])

# Sheet 6: Semua Hasil Cross-Check
ws6 = wb.create_sheet("Semua Hasil Cross-Check")
for r_idx, row in enumerate(dataframe_to_rows(results_df, index=False, header=True), 1):
    ws6.append(row)
style_worksheet(ws6, results_df, highlight_col=10, approve_value="TIDAK DITEMUKAN", reject_value="DITEMUKAN")

# Simpan file Excel
excel_filename = 'HASIL_FILTER_PESERTA_LENGKAP.xlsx'
wb.save(excel_filename)

print(f"\n✅ File Excel berhasil disimpan: {excel_filename}")
print(f"\n📋 DAFTAR SHEETS DALAM FILE EXCEL:")
print(f"   1. Dashboard Summary      - Ringkasan keseluruhan")
print(f"   2. APPROVE - Belum Ujian  - 🟢 Peserta yang layak di-approve ({len(recommended_for_approval)} peserta)")
print(f"   3. JANGAN APPROVE         - 🔴 Peserta yang sudah ujian ({len(not_recommended)} peserta)")
print(f"   4. VERIFIKASI             - 🟡 Matching perlu dicek ulang")
print(f"   5. REVIEW - Pernah Gagal  - 🟡 Peserta pernah gagal daftar lagi")
print(f"   6. Semua Hasil Cross-Check - Detail lengkap semua peserta")
print(f"\n💡 Tips: Buka file Excel, gunakan filter & sorting untuk review lebih mudah!")
print(f"   - Hijau = Layak di-approve")
print(f"   - Merah = Jangan di-approve")
print(f"   - Kuning = Perlu review manual")
# Out:
# ======================================================================
# 📊 EXPORT KE EXCEL DENGAN MULTIPLE SHEETS & HIGHLIGHTING
# ======================================================================
# ✅ Library openpyxl tersedia
#
# ✅ File Excel berhasil disimpan: HASIL_FILTER_PESERTA_LENGKAP.xlsx
#
# 📋 DAFTAR SHEETS DALAM FILE EXCEL:
#    1. Dashboard Summary      - Ringkasan keseluruhan
#    2. APPROVE - Belum Ujian  - 🟢 Peserta yang layak di-approve (20 peserta)
#    3. JANGAN APPROVE         - 🔴 Peserta yang sudah ujian (52 peserta)
#    4. VERIFIKASI             - 🟡 Matching perlu dicek ulang
#    5. REVIEW - Pernah Gagal  - 🟡 Peserta pernah gagal daftar lagi
#    6. Semua Hasil Cross-Check - Detail lengkap semua peserta
#
# 💡 Tips: Buka file Excel, gunakan filter & sorting untuk review lebih mudah!
#    - Hijau = Layak di-approve
#    - Merah = Jangan di-approve
#    - Kuning = Perlu review manual

# %%
# ========== FITUR 6: CROSS-CHECK FORM KEIKUTSERTAAN SERTIFIKASI ==========
print(f"\n{'=' * 80}")
print("📋 CROSS-CHECK FORM KEIKUTSERTAAN SERTIFIKASI KOMPETENSI")
print(f"=" * 80)

# Load data form keikutsertaan
form_df = pd.read_csv('FORM KEIKUTSERTAAN SERTIFIKASI KOMPETENSI.csv')

# Bersihkan dan siapkan data
form_df['NAMA LENGKAP'] = form_df['NAMA LENGKAP'].fillna('').str.strip().str.upper()
form_df['NIM (Nomor Induk Mahasiswa)'] = form_df['NIM (Nomor Induk Mahasiswa)'].astype(str).str.strip()

# Gabungkan Email (prioritas Email, jika kosong gunakan Email2)
form_df['Email Final'] = form_df.apply(
    lambda row: row['Email'] if pd.notna(row['Email']) and row['Email'] != 'anonymous' and str(row['Email']).strip() != '' 
    else (row['Email2'] if pd.notna(row['Email2']) and str(row['Email2']).strip() != '' else '-'),
    axis=1
)

# Tentukan sumber (MCF atau MOS) berdasarkan program yang dipilih
def tentukan_sumber_form(row):
    prog1 = str(row.get('PILIH PROGRAM SERTIFIKASI YANG SUDAH PERNAH DIAMBIL', '')).upper()
    prog2 = str(row.get('PILIH PROGRAM SERTIFIKASI YANG SUDAH PERNAH DIAMBIL2', '')).upper()
    subprog_combined = str(row.get('PILIH SUBPROGRAM', '')).upper()
    
    # Cek apakah ada AZURE atau MCF
    if 'AZURE' in subprog_combined or 'MCF' in prog1 or 'MCF' in prog2 or 'CERTIFIED FUNDAMENTALS' in prog2:
        return 'MCF'
    # Kalau tidak, default ke MOS
    else:
        return 'MOS'

form_df['Sumber'] = form_df.apply(tentukan_sumber_form, axis=1)

# Tentukan subprogram yang dipilih (gabungkan semua kolom subprogram)
def get_subprogram(row):
    submos = str(row.get('PILIH SUBPROGRAM MOS', ''))
    submcf = str(row.get('PILIH SUBPROGRAM MCF', ''))
    subprog = str(row.get('PILIH SUBPROGRAM', ''))
    
    # Gabungkan semua subprogram yang ada
    hasil = []
    if submos and submos != 'nan' and submos.strip():
        hasil.append(submos.strip())
    if submcf and submcf != 'nan' and submcf.strip():
        hasil.append(submcf.strip())
    if subprog and subprog != 'nan' and subprog.strip():
        hasil.append(subprog.strip())
    
    return ' & '.join(hasil) if hasil else '-'

form_df['Subprogram'] = form_df.apply(get_subprogram, axis=1)

print(f"Total data dari Form Keikutsertaan: {len(form_df)}")
print(f"\n--- Breakdown Sumber ---")
print(form_df['Sumber'].value_counts().to_string())
print(f"\n--- Preview Data ---")
print(form_df[['NAMA LENGKAP', 'NIM (Nomor Induk Mahasiswa)', 'Email Final', 'Sumber', 'Subprogram']].head(10).to_string(index=False))
# Out:
# ================================================================================
# 📋 CROSS-CHECK FORM KEIKUTSERTAAN SERTIFIKASI KOMPETENSI
# ================================================================================
# Total data dari Form Keikutsertaan: 159
#
# --- Breakdown Sumber ---
# Sumber
# MOS    155
# MCF      4
#
# --- Preview Data ---
#               NAMA LENGKAP NIM (Nomor Induk Mahasiswa)                   Email Final Sumber                                    Subprogram
#         RATU ADISYA FAMELA                   202231105       ratu2231105@itpln.ac.id    MOS                         MOS: Office Word 2019
#     MUHAMMAD RAIHAN AZZAKY                   202241017     raihan2241017@itpln.ac.id    MOS                        MOS: Office Excel 2019
#          VIA ISNATUL LAILA                   202241013 viaisnatul2241013@itpln.ac.id    MOS                         MOS: Office Word 2019
#       NAUFAL YURFANA AISAL                   202241012     naufal2241012@itpln.ac.id    MOS                         MOS: Office Word 2019
#       WIDY SYAFITRI SLAMET                   202231070       Widy2231070@itpln.ac.id    MOS                         MOS: Office Word 2019
#     YEREMIA JUAN SABASTIAN                   202212007    Yeremia2212007@itpln.ac.id    MOS                         MOS: Office Word 2019
#       RENNY AMELIA BANTOTO                   202231071      Renny2231071@itpln.ac.id    MOS                         MOS: Office Word 2019
# ALVAN YAVIN JONATAN SIRAIT                   202112057      alvan2112057@itpln.ac.id    MOS                         MOS: Office Word 2019
#            INDAH WULANDARI                   202231051      Indah2231051@itpln.ac.id    MOS                         MOS: Office Word 2019
#    WILLIAM HARUN INFAINDAN                   201931223    WILLIAM1931223@itpln.ac.id    MCF MOS: Office Word 2019 & Azure AI Fundamentals

# %%
# ========== PROSES CROSS-CHECK FORM DENGAN CERTIPORT ==========
print(f"\n{'=' * 80}")
print("🔍 PROSES CROSS-CHECK FORM KEIKUTSERTAAN DENGAN CERTIPORT")
print(f"=" * 80)

# Hasil matching untuk form
form_results = []

for idx, row in form_df.iterrows():
    nama = row['NAMA LENGKAP']
    nim = row['NIM (Nomor Induk Mahasiswa)']
    email = row['Email']
    email2 = row['Email2']
    email_final = row['Email Final']
    sumber = row['Sumber']
    subprogram = row['Subprogram']
    prodi = row.get('PROGRAM STUDI', '-')
    
    # Pilih database certiport sesuai sumber
    if sumber == 'MCF':
        certiport_names = certiport_mcf_names
    else:
        certiport_names = certiport_mos_names
    
    # Cari kecocokan
    match, score, match_type = find_best_match(nama, certiport_names)
    
    form_results.append({
        'Nama Lengkap': nama,
        'NIM': nim,
        'Email': email if pd.notna(email) else '-',
        'Email2': email2 if pd.notna(email2) else '-',
        'Email Final': email_final,
        'Program Studi': prodi,
        'Sumber': sumber,
        'Subprogram': subprogram,
        'Nama di Certiport': match if match else '-',
        'Skor Kecocokan': score,
        'Tipe Match': match_type,
        'Status': '✅ DITEMUKAN - Sudah Ujian' if match else '❌ TIDAK DITEMUKAN - Belum Ujian',
        'Rekomendasi': '❌ JANGAN APPROVE - Sudah Pernah Ujian' if match else '✅ APPROVE - Belum Pernah Ujian'
    })

# Buat DataFrame hasil
form_results_df = pd.DataFrame(form_results)

# Pisahkan hasil berdasarkan Status
form_approve = form_results_df[form_results_df['Status'].str.contains('TIDAK DITEMUKAN')].copy()
form_jangan_approve = form_results_df[form_results_df['Status'].str.contains('DITEMUKAN') & ~form_results_df['Status'].str.contains('TIDAK')].copy()

print(f"\nHasil Cross-Check Form Keikutsertaan:")
print(f"   ✅ APPROVE (Belum Pernah Ujian): {len(form_approve)} peserta")
print(f"   ❌ JANGAN APPROVE (Sudah Ujian): {len(form_jangan_approve)} peserta")

print(f"\n--- Breakdown per Sumber ---")
print(form_results_df.groupby(['Sumber', 'Status']).size().unstack(fill_value=0))
# Out:
# ================================================================================
# 🔍 PROSES CROSS-CHECK FORM KEIKUTSERTAAN DENGAN CERTIPORT
# ================================================================================
#
# Hasil Cross-Check Form Keikutsertaan:
#    ✅ APPROVE (Belum Pernah Ujian): 24 peserta
#    ❌ JANGAN APPROVE (Sudah Ujian): 135 peserta
#
# --- Breakdown per Sumber ---
# Status  ✅ DITEMUKAN - Sudah Ujian  ❌ TIDAK DITEMUKAN - Belum Ujian
# Sumber
# MCF                             2                                2
# MOS                           133                               22

# %%
# ========== TAMPILKAN DETAIL HASIL FORM KEIKUTSERTAAN ==========
print(f"\n{'=' * 80}")
print("✅ PESERTA FORM YANG LAYAK DI-APPROVE (Belum Pernah Ujian)")
print(f"=" * 80)
if len(form_approve) > 0:
    print(form_approve[['Nama Lengkap', 'NIM', 'Email Final', 'Sumber', 'Subprogram', 'Rekomendasi']].to_string(index=False))
else:
    print("Tidak ada peserta yang layak di-approve")

print(f"\n{'=' * 80}")
print("❌ PESERTA FORM YANG JANGAN DI-APPROVE (Sudah Pernah Ujian)")
print(f"=" * 80)
if len(form_jangan_approve) > 0:
    print(form_jangan_approve[['Nama Lengkap', 'NIM', 'Email Final', 'Sumber', 'Nama di Certiport', 'Skor Kecocokan', 'Rekomendasi']].to_string(index=False))
else:
    print("Tidak ada peserta yang sudah pernah ujian")
# Out:
# ================================================================================
# ✅ PESERTA FORM YANG LAYAK DI-APPROVE (Belum Pernah Ujian)
# ================================================================================
#                    Nama Lengkap       NIM                                       Email Final Sumber            Subprogram                    Rekomendasi
#              JAPAR SIRINGORINGO 202214045                          japar2214045@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#              JAPAR SIRINGORINGO 202214045                          japar2214045@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#      LALU MUHAMMAD RISGAN NAZWA 202231009                           Lalu2231009@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#         ANNA FINCE MARIANA WOUW 202111062                           anna2111062@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#            HARTANTO TRI SUBEKTI 202214010                       Hartanto2214010@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#               MEIPIZA YUDISTIRA 202214011                        Meipiza2214011@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#          MUHAMMAD SHIHAB TIBYAN 202214017                       Muhammad2214017@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
# MUHAMMAD FATHURRAHMAN AL MUNZIR 202214035                           fath2214035@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#             LALU PARHAN HIDAYAT 202212023                           Lalu2212023@itpln.ac.id    MOS  MOS: Office PPT 2019 ✅ APPROVE - Belum Pernah Ujian
#             BAGUS HARIE RACHMAN 202212021                          Bagus2212021@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#            ARIEL GIORDAN WIJAYA 202211048                          Ariel2211048@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#         NAWAAL HIKMAH KURNIAWAN 202232008                         Nawaal2232008@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#                     ASNUR FAJRI 202212006                          Asnur2212006@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#           ADITYA FATHIN MUBAROK 202211124                         aditya2211124@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#           MUHAMMAD SAHRUL MUBIN 201911199                                                 -    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#               RAFI IRSYAD MAHDI 202242017                         rafiirsyadmahdi@gmail.com    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#               RAFI IRSYAD MAHDI 202242017 rafiirsyadmahdi@gmail.com/Rafi2242017@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#                  FIRMAN ANSHARI 202331136                      firmanimmank130902@gmail.com    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#              HEZKYA FEBRYKUSUMA 202214038                         hezkya2214038@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#          MUHAMMAD FAQIH NEFAWAN 202231113                          faqih2231113@itpln.ac.id    MCF Azure AI Fundamentals ✅ APPROVE - Belum Pernah Ujian
#             ANDI RAYHAN ALFIQHI 202211037                           andi2211037@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#              ANDRE DIKA PRATAMA 202214036                          andre2214036@itpln.ac.id    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#             AYU PURNAMA BINTANG 202211096                                 ayuwhoa@gmail.com    MOS MOS: Office Word 2019 ✅ APPROVE - Belum Pernah Ujian
#               LUTFIANSYAH MAJID 202131129                    lutfiansyah2131129@itpln.ac.id    MCF Azure AI Fundamentals ✅ APPROVE - Belum Pernah Ujian
#
# ================================================================================
# ❌ PESERTA FORM YANG JANGAN DI-APPROVE (Sudah Pernah Ujian)
# ================================================================================
#                                 Nama Lengkap         NIM                                           Email Final Sumber                  Nama di Certiport  Skor Kecocokan                           Rekomendasi
#                           RATU ADISYA FAMELA   202231105                               ratu2231105@itpln.ac.id    MOS                        RATU FAMELA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       MUHAMMAD RAIHAN AZZAKY   202241017                             raihan2241017@itpln.ac.id    MOS             MUHAMMAD RAIHAN AZZAKY             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            VIA ISNATUL LAILA   202241013                         viaisnatul2241013@itpln.ac.id    MOS                          VIA LAILA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         NAUFAL YURFANA AISAL   202241012                             naufal2241012@itpln.ac.id    MOS                       NAUFAL AISAL             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         WIDY SYAFITRI SLAMET   202231070                               Widy2231070@itpln.ac.id    MOS                        WIDY SLAMET             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       YEREMIA JUAN SABASTIAN   202212007                            Yeremia2212007@itpln.ac.id    MOS                  YEREMIA SABASTIAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         RENNY AMELIA BANTOTO   202231071                              Renny2231071@itpln.ac.id    MOS                      RENNY BANTOTO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   ALVAN YAVIN JONATAN SIRAIT   202112057                              alvan2112057@itpln.ac.id    MOS         ALVAN YAVIN JONATAN SIRAIT             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              INDAH WULANDARI   202231051                              Indah2231051@itpln.ac.id    MOS                    INDAH WULANDARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      WILLIAM HARUN INFAINDAN   201931223                            WILLIAM1931223@itpln.ac.id    MCF            WILLIAM HARUN INFAINDAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          LILI NUR INDAH SARI   202211003                               Lili2211003@itpln.ac.id    MOS                    LILI INDAH SARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        JIHAN AZZAHRA DIOVANT   202212037                              jihan2212037@itpln.ac.id    MOS              JIHAN AZZAHRA DIOVANT             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            AJENG PUSPITALOKA   202231043                              Ajeng2231043@itpln.ac.id    MOS                  AJENG PUSPITALOKA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          FA'IZ AULIA RAKHMAN   202215006                               faiz2215006@itpln.ac.id    MOS                       FAIZ RAKHMAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        T.RAJAS SUHABA ARWANA   202231035                                  T2231035@itpln.ac.id    MOS              T.RAJAS SUHABA ARWANA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                    REKSI WULAN KINASIH GUSTI   202241008                              Reksi2241008@itpln.ac.id    MOS          REKSI WULAN KINASIH GUSTI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      SULTHON MUHAMMAD NAZHIF   202242008                            Sulthon2242008@itpln.ac.id    MOS                     SULTHON NAZHIF             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                 NAZWA ALIFYA   202211111                              nazwa2211111@itpln.ac.id    MOS                       NAZWA ALIFYA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         BAIQ PUTRI SUARTIKHA   202232023                               baiq2232023@itpln.ac.id    MOS                     BAIQ SUARTIKHA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          MARIA ANJELINA PENI   202241014                              maria2241014@itpln.ac.id    MOS                         MARIA PENI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                JEVON GOEYANA   202211002                              Jevon2211002@itpln.ac.id    MOS                      JEVON GOEYANA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      NUR ICHLAS INSANI RAMLI   202211081                                Nur2211081@itpln.ac.id    MOS            NUR ICHLAS INSANI RAMLI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          NADELLA EZI SABRINA   202232010                            Nadella2232010@itpln.ac.id    MOS                    NADELLA SABRINA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         AKMAL DZAKY ADHYNATA   202212021                              akmal2212031@itpln.ac.id    MOS                     AKMAL ADHYNATA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                 MUHAMMAD RIZKY BAMBY SAPUTRA   202232002                           Muhammad2232002@itpln.ac.id    MOS             MUHAMMAD RIZKY SAPUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        JUAN GERALD ARITONANG   202232007                               Juan2232007@itpln.ac.id    MOS                     JUAN ARITONANG             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      TARISA DWINA ARTHANEVIA   202232022                             tarisa2232022@itpln.ac.id    MOS                  TARISA ARTHANEVIA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       VIVIN MELANESYA WAYENI   202131047                              vivin2131047@itpln.ac.id    MOS             VIVIN MELANESYA WAYENI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        WAHID YAMINSYAH PUTRA   202231040                              Wahid2231040@itpln.ac.id    MOS                        WAHID PUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              GALIH RAKA SIWI   202231060                              Galih2231060@itpln.ac.id    MOS                         GALIH SIWI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   ALDHA NITHA TRY WULAN SARI   202231057                              Aldha2231057@itpln.ac.id    MOS                   ALDHA NITHA SARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#           MUHAMMAD REVIANSYAH DANENDRA PUTRA   202131160                               revi2131160@itpln.ac.id    MOS MUHAMMAD REVIANSYAH DANENDRA PUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#             RITCHIE CHORINUS TIOLUNG MAABUAT   202211088                            Ritchie2211088@itpln.ac.id    MOS                    RITCHIE MAABUAT             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          SANDIKA LAODE NAMBO   202011201                            sandika2011201@itpln.ac.id    MOS                SANDIKA LAODE NAMBO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   ANNISA RISQINA PUTRI AULIA   202241005                             Annisa2241005@itpln.ac.id    MOS         ANNISA RISQINA PUTRI AULIA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          AISYAH TRI NURFAJRI   202231064                             Aisyah2231064@itpln.ac.id    MOS                    AISYAH NURFAJRI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            MEY EKLISYE AYOMI   202214031                                mey2214031@itpln.ac.id    MOS                  MEY EKLISYE AYOMI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                               RIZKY RAMADHAN   202212038                              rizky2212038@itpln.ac.id    MOS                     RIZKY RAMADHAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     SYAIFULLAH YUSUF SAPUTRA   202212523                         syaifullah2212523@itpln.ac.id    MOS           SYAIFULLAH YUSUF SAPUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     DWIANTORO AZKA NAYOTTAMA   202212039                          dwiantoro2212039@itpln.ac.id    MOS                DWIANTORO NAYOTTAMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            DAVID AJI PRAYOGA   202211050                              David2211050@itpln.ac.id    MOS                      DAVID PRAYOGA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#               DESTA AZRA ROSANI FEERLIAN ADI   202232033                              desta2232033@itpln.ac.id    MOS            DESTA AZRA FEERLIAN ADI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       FUFUN AGITHA FUNIAYUNG   202232030                              fufun2232030@itpln.ac.id    MOS             FUFUN AGITHA FUNIAYUNG             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                    ANDI MUHAMMAD NABIL ALKAF   202231112                               andi2231112@itpln.ac.id    MOS                     MUHAMMAD NABIL             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            DANI ABID ASSINDI   202211079                               Dani2211079@itpln.ac.id    MOS                       DANI ASSINDI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       SALWA NAGITA MAULUDINI   202231034                              Salwa2231034@itpln.ac.id    MOS                    SALWA MAULUDINI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     SARAH AISYAH KUSUMAHARJO   202211086                              Sarah2211086@itpln.ac.id    MOS                  SARAH KUSUMAHARJO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      FOEZY IMROATUL AWALIYAH   202212019                                    bemkbm@itpln.ac.id    MOS            FOEZY IMROATUL AWALIYAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              NUR KOMALA SARI   202212014                                Nur2212014@itpln.ac.id    MOS                    NUR KOMALA SARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        TIFFANY AMELIA EFENDI   202232021                            tiffany2232021@itpln.ac.id    MOS                     TIFFANY EFENDI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                               SHERLY WAHYUNI   202131073                             sherly2131073@itpln.ac.id    MCF                     SHERLY WAHYUNI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                    MUHAMMAD RIFQI APRIANSYAH   202231104                              rifqi2231104@itpln.ac.id    MOS          MUHAMMAD RIFQI APRIANSYAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      MUHAMMAD RAFI AL ANBIYA   202231089                               rafi2231089@itpln.ac.id    MOS                 MUHAMMAD AL ANBIYA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         MUHAMMAD HELMI ABBAD   202212020                           Muhammad2212020@itpln.ac.id    MOS               MUHAMMAD HELMI ABBAD             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       FARREL LAOGI MURJITAMA   202231096                             farrel2231096@itpln.ac.id    MOS                   FARREL MURJITAMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                  MUHAMMAD HILMI FIKRI FAUZAN   202212018                           Muhammad2212018@itpln.ac.id    MOS              MUHAMMAD HILMI FAUZAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          HUMAYRA QATHRUNNADA   202232027                            humayra2232027@itpln.ac.id    MOS                HUMAYRA QATHRUNNADA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            MELYSA RAMADIANTI   202232003                             Melysa2232003@itpln.ac.id    MOS                  MELYSA RAMADIANTI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        MUHAMMAD RAFI PRATAMA   202211141                               rafi2232501@itpln.ac.id    MOS                   MUHAMMAD PRATAMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         NUR RAHMADANI WIGUNA   202221015                                Nur2221015@itpln.ac.id    MOS                         NUR WIGUNA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       JOHN ANDREW TAMPUBOLON   202211153                               john2211153@itpln.ac.id    MOS             JOHN ANDREW TAMPUBOLON             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       MUHAMMAD SADDAM WIJAYA   202011316                             saddam2011316@itpln.ac.id    MOS                    MUHAMMAD WIJAYA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         AZHAR LAZUARDI IMANI   202211136                              azhar2211136@itpln.ac.id    MOS                        AZHAR IMANI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                           RISHA FIRLY APSARI   202242022                              risha2242022@itpln.ac.id    MOS                       RISHA APSARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                  JOY MELANIA   202242019                                joy2242019@itpln.ac.id    MOS                        JOY MELANIA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                           LILY FITRI HASANAH   202231001                               Lily2231001@itpln.ac.id    MOS                 LILY FITRI HASANAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                  RAFI KARTIKA GALIH PRAMESTI   202212035                               rafi2212035@itpln.ac.id    MOS        RAFI KARTIKA GALIH PRAMESTI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          YUDHISTIRA HARDJALI   202212004                         Yudhistira2212004@itpln.ac.id    MOS                YUDHISTIRA HARDJALI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                  MUHAMMAD NAUFAL HARDIANSYAH   202212011                           Muhammad2212011@itpln.ac.id    MOS               MUHAMMAD HARDIANSYAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                  ROVAN LUWID ERVAN SIHOMBING   202212002                              Rovan2212002@itpln.ac.id    MOS                    ROVAN SIHOMBING             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                AHMAD SUDARNO   202212520                              ahmad2212520@itpln.ac.id    MOS                      AHMAD SUDARNO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              RIUVANDA TRIANO   202212010                           Riuvanda2212010@itpln.ac.id    MOS                    RIUVANDA TRIANO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              RAYHAN GHASSANI   202214012                             Rayhan2214012@itpln.ac.id    MOS                    RAYHAN GHASSANI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                      HUMAIDA   202211121                            humaida2211121@itpln.ac.id    MOS                            HUMAIDA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        HALQI WIHARYA SAPUTRA 202232012l3                              Halqi2232013@itpln.ac.id    MOS              HALQI WIHARYA SAPUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                WIJAYA KUSUMA   202212026                                wijaya230604@gmail.com    MOS                      WIJAYA KUSUMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          FRENGKI JOSUA PURBA   202131193                            frengki2131193@itpln.ac.id    MOS                FRENGKI JOSUA PURBA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#          FIDELIS KISNARDI KUNCORO BUTARBUTAR   202211031                            fidelis2211031@itpln.ac.id    MOS                 FIDELIS BUTARBUTAR             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                               ABDUL FARISDIN   202232020                              abdul2232020@itpln.ac.id    MOS                     ABDUL FARISDIN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        MUHAMMAD NAUFAL ARIEF   202231026                                    n4uf4l55@gmail.com    MOS              MUHAMMAD NAUFAL ARIEF             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         ZAGHI PRIMA MANGGALA   202242006                              primanggalaz87@gmail.com    MOS                     ZAGHI MANGGALA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         AKMAL DZAKY ADHYNATA   202212031                          akmaldzakyadhynata@gmail.com    MOS                     AKMAL ADHYNATA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     RIEKE WAHYUNING PITALOKA   202214040                             riekewahyuning2@gmail.com    MOS                     RIEKE PITALOKA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                            VIA ISNATUL LAILA   202241013                         Viaisnatul2241013@itpln.ac.id    MOS                          VIA LAILA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                 MUHAMMAD WAHYU GUSTIAN HARUN   202214039                              wahyu2214039@itpln.ac.id    MOS               MUHAMMAD WAHYU ILHAM              82 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                             LASMA DEVI ARUAN   202111143                              lasma2111143@itpln.ac.id    MOS                        LASMA ARUAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     RIEKE WAHYUNING PITALOKA   202214040                             riekewahyuning2@gmail.com    MOS                     RIEKE PITALOKA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                 MUHAMMAD WAHYU GUSTIAN HARUN   202214039                              wahyu2214039@itpln.ac.id    MOS               MUHAMMAD WAHYU ILHAM              82 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          RISNA RIZKY ALFIYAN   202214021                              Risna2214021@itpln.ac.id    MOS                RISNA RIZKY ALFIYAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                RISWANDI ARIF   202212017                              riswandiarif89@gmail.com    MOS                      RISWANDI ARIF             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                 DEJAN ABIYYU   202242040                              dejan2242040@itpln.ac.id    MOS                       DEJAN ABIYYU             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         RIZA SAGITA IMANIZAR   302242015                              Sagitaaagita23@gmail.com    MOS                      RIZA IMANIZAR             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                             ABDURAHMAN KINKY   202214044                                   kayyssy14@gmail.com    MOS                   ABDURAHMAN KINKY             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                               ANNISA FAUZIAH   202242020 annisaafauziahh@gmail.com / annisa2242020@itpln.ac.id    MOS                     ANNISA FAUZIAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                               ALFIYAH RAHMAH   202242010                            alfiyah2242010@itpln.ac.id    MOS                     ALFIYAH RAHMAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#            ROSEMAIN ERI ASTUTI JATNIKA PUTRI   202242028                           rosemain2242028@itpln.ac.id    MOS                     ROSEMAIN PUTRI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      CLOUDYA HILL LOVELY BIU   202242016                            Cloudya2242016@itpln.ac.id    MOS            CLOUDYA HILL LOVELY BIU             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                           DIAH NITA MUSLIHAH   202242007                               diah2242007@itpln.ac.id    MOS                      DIAH MUSLIHAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   ALISYA SULIFIANTI BAHASOAN   202242024                             alisya2242024@itpln.ac.id    MOS                    ALISYA BAHASOAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       DUCKY SEMI TELAUMBANUA   202242030                              ducky2242030@itpln.ac.id    MOS                  DUCKY TELAUMBANUA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              PLASIDUS CHARLY   202242032                           plasidus2242032@itpln.ac.id    MOS                    PLASIDUS CHARLY             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                  ANDI AISYAH   202242023                               andi2242023@itpln.ac.id    MOS                        ANDI AISYAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#             DWI PUTRI NABILA ARIYHANI WIBOWO   202242033                                dwi2242033@itpln.ac.id    MOS                          DWI PUTRI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        FIKRI AHMAD AMIRULLOH   202242031                              fikri2242031@itpln.ac.id    MOS              FIKRI AHMAD AMIRULLOH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     RIEKE WAHYUNING PITALOKA   202214040                              rieke2214040@itpln.ac.id    MOS                     RIEKE PITALOKA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                              PLASIDUS CHARLY   202242032                           plasidus2242032@itpln.ac.id    MOS                    PLASIDUS CHARLY             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#           MUHAMMAD REVIANSYAH DANENDRA PUTRA   202131160                               revi2131160@itpln.ac.id    MOS MUHAMMAD REVIANSYAH DANENDRA PUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      PRATITYA BHUMI WIBANGGA   202242009                           Pratitya2242009@itpln.ac.id    MOS                  PRATITYA WIBANGGA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#         JENNIFER GABRIELLE OUCTORIN PONGTIKU   202242026                           jennifer2242026@itpln.ac.id    MOS                  JENNIFER PONGTIKU             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         RIZA SAGITA IMANIZAR   202242015                               Riza2242015@itpln.ac.id    MOS                      RIZA IMANIZAR             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                 DONI PRATAMA   202111119                                    prtm2405@gmail.com    MOS                       DONI PRATAMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      MUHAMMAD ABIYYU PRATAMA   202211103                                   abiyubiyu@gmail.com    MOS                   MUHAMMAD PRATAMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
# MUHAMMAD FEBRIANSYAH ADITYA PRATAMA PUTRA SM   202111077                        muhfebriansyahaditya@gmail.com    MOS               MUHAMMAD FEBRIANSYAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                     NENENG AGUSTIEN SOLEKHAH   202221033                                  neneng317e@gmail.com    MOS                    NENENG SOLEKHAH             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   YERICHO HARVEY KRISETYANTO   202231012                           Yericho2231012@itpln.ac.id     MOS                YERICHO KRISETYANTO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          MUHAMAD RAIS ABQARI   202221026                                 mraisabqari@gmail.com    MOS                     MUHAMAD ABQARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       YEREMIA JUAN SABASTIAN   202212007                            Yeremia2212007@itpln.ac.id    MOS                  YEREMIA SABASTIAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       MUHAMMAD FAQIH RABBANI   202242001                           Muhammad2242001@itpln.ac.id    MOS             MUHAMMAD HILMI RABBANI              84 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                      ARIO YOGATAMA ERLAPUTRA   202242012                               ario2242012@itpln.ac.id    MOS                     ARIO ERLAPUTRA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         YUDITH NADHIRA AYUVA   202221009                             Yudith2221009@itpln.ac.id    MOS                       YUDITH AYUVA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          DWI RENO OKTA RIADI   202231124                                Dwi2231124@itpln.ac.id    MOS                DWI RENO OKTA RIADI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         YUDITH NADHIRA AYUVA   202221009                             Yudith2221009@itpln.ac.id    MOS                       YUDITH AYUVA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                             CYNTHIA MAHARANI   202231046                            cynthia2231046@itpln.ac.id    MOS                   CYNTHIA MAHARANI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   ALVAN YAVIN JONATAN SIRAIT   202112057                                Alvansirait3@gmail.com    MOS         ALVAN YAVIN JONATAN SIRAIT             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                    SRI AULIA   Sri Aulia                                Sri2211035@itpln.ac.id    MOS                          SRI AULIA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        NUR MUTMAINNAH HASRUL   202231090                                nur2231090@itpln.ac.id    MOS                         NUR HASRUL             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                 AKMAL HAWARI   202212042                              akmalhawari007@gmail.com    MOS                       AKMAL HAWARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                                 AKMAL HAWARI   202212042                              akmalhawari007@gmail.com    MOS                       AKMAL HAWARI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                  MUHAMMAD HILMI FIKRI FAUZAN   202212018                           muhammad2212018@itpln.ac.id    MOS              MUHAMMAD HILMI FAUZAN             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                        HARDIVE TRI PRASETIYO   202211026                            Hardive2211026@itpln.ac.id    MOS                  HARDIVE PRASETIYO             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                          RIDHO HAMZAH SAGALA   202211038                              Ridho2211038@itpln.ac.id    MOS                       RIDHO SAGALA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                       MUHAMAD RIZKI RAMDALIS   202212022                            muhamad2212022@itpln.ac.id    MOS                  MUHAMAD RIZKI YAN              88 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                         AZHAR LAZUARDI IMANI   202211136                              azhar2211136@itpln.ac.id    MOS                        AZHAR IMANI             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   SACHARISSA SHERLY LUHULIMA   202211085                         sacharissa2211085@itpln.ac.id    MOS         SACHARISSA SHERLY LUHULIMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian
#                   SACHARISSA SHERLY LUHULIMA   202211085                         sacharissa2211085@itpln.ac.id    MOS         SACHARISSA SHERLY LUHULIMA             100 ❌ JANGAN APPROVE - Sudah Pernah Ujian

# %%
# ========== EXPORT HASIL FORM KEIKUTSERTAAN KE CSV ==========
print("🔄 Menyimpan hasil Form Keikutsertaan ke CSV...")

# Kolom yang akan di-export untuk Form APPROVE
form_approve_export = form_approve[['Nama Lengkap', 'NIM', 'Email', 'Email2', 'Email Final', 'Sumber', 'Subprogram', 'Rekomendasi']].copy()
form_approve_export.to_csv('FORM_APPROVE_belum_ujian.csv', index=False, encoding='utf-8-sig')
print(f"✅ Tersimpan: FORM_APPROVE_belum_ujian.csv ({len(form_approve_export)} peserta)")

# Kolom yang akan di-export untuk Form JANGAN APPROVE
form_jangan_approve_export = form_jangan_approve[['Nama Lengkap', 'NIM', 'Email', 'Email2', 'Email Final', 
                                                   'Sumber', 'Subprogram', 'Nama di Certiport', 
                                                   'Skor Kecocokan', 'Rekomendasi']].copy()
form_jangan_approve_export.to_csv('FORM_JANGAN_APPROVE_sudah_ujian.csv', index=False, encoding='utf-8-sig')
print(f"✅ Tersimpan: FORM_JANGAN_APPROVE_sudah_ujian.csv ({len(form_jangan_approve_export)} peserta)")

print("\n📊 Ringkasan Export CSV Form Keikutsertaan:")
print(f"   - Form APPROVE (Belum Ujian): {len(form_approve_export)} peserta")
print(f"   - Form JANGAN APPROVE (Sudah Ujian): {len(form_jangan_approve_export)} peserta")
# Out:
# 🔄 Menyimpan hasil Form Keikutsertaan ke CSV...
# ✅ Tersimpan: FORM_APPROVE_belum_ujian.csv (24 peserta)
# ✅ Tersimpan: FORM_JANGAN_APPROVE_sudah_ujian.csv (135 peserta)
#
# 📊 Ringkasan Export CSV Form Keikutsertaan:
#    - Form APPROVE (Belum Ujian): 24 peserta
#    - Form JANGAN APPROVE (Sudah Ujian): 135 peserta

# %%
# ========== EXPORT FORM KEIKUTSERTAAN KE EXCEL TERPISAH ==========
from openpyxl import Workbook
from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
from openpyxl.utils.dataframe import dataframe_to_rows

print(f"\n{'=' * 80}")
print("📊 EXPORT HASIL FORM KEIKUTSERTAAN KE EXCEL (FILE TERPISAH)")
print(f"=" * 80)

# Buat workbook BARU untuk Form Keikutsertaan
wb_form = Workbook()

# Style definitions
green_fill = PatternFill(start_color='90EE90', end_color='90EE90', fill_type='solid')
red_fill = PatternFill(start_color='FFB6C1', end_color='FFB6C1', fill_type='solid')
yellow_fill = PatternFill(start_color='FFEB9C', end_color='FFEB9C', fill_type='solid')
header_fill = PatternFill(start_color='4472C4', end_color='4472C4', fill_type='solid')
header_font = Font(bold=True, color='FFFFFF')
thin_border = Border(
    left=Side(style='thin'),
    right=Side(style='thin'),
    top=Side(style='thin'),
    bottom=Side(style='thin')
)

# ========== SHEET 1: Dashboard Summary Form Keikutsertaan ==========
ws_summary = wb_form.active
ws_summary.title = "Dashboard Summary"
summary_form_data = [
    ["KATEGORI", "JUMLAH", "PERSENTASE", "STATUS"],
    ["Total Pendaftar Form", len(form_df), "100%", "ℹ️"],
    ["  ├─ MCF (Azure AI-900)", len(form_df[form_df['Sumber'] == 'MCF']), f"{len(form_df[form_df['Sumber'] == 'MCF'])/len(form_df)*100:.1f}%", ""],
    ["  └─ MOS (Office 2019)", len(form_df[form_df['Sumber'] == 'MOS']), f"{len(form_df[form_df['Sumber'] == 'MOS'])/len(form_df)*100:.1f}%", ""],
    ["", "", "", ""],
    ["Sudah Pernah Ujian", len(form_jangan_approve), f"{len(form_jangan_approve)/len(form_df)*100:.1f}%", "❌ JANGAN APPROVE"],
    ["Belum Pernah Ujian", len(form_approve), f"{len(form_approve)/len(form_df)*100:.1f}%", "✅ APPROVE"],
]
for row in summary_form_data:
    ws_summary.append(row)

# Style dashboard summary
for cell in ws_summary[1]:
    cell.fill = header_fill
    cell.font = header_font
    cell.alignment = Alignment(horizontal='center')
    cell.border = thin_border

for row_idx in range(2, ws_summary.max_row + 1):
    for col_idx in range(1, 5):
        cell = ws_summary.cell(row=row_idx, column=col_idx)
        cell.border = thin_border
        status_cell = ws_summary.cell(row=row_idx, column=4)
        if "APPROVE" in str(status_cell.value) and "JANGAN" not in str(status_cell.value):
            for c in range(1, 5):
                ws_summary.cell(row=row_idx, column=c).fill = green_fill
        elif "JANGAN" in str(status_cell.value):
            for c in range(1, 5):
                ws_summary.cell(row=row_idx, column=c).fill = red_fill

for col_idx in range(1, 5):
    ws_summary.column_dimensions[ws_summary.cell(row=1, column=col_idx).column_letter].width = 25

# ========== SHEET 2: APPROVE (Belum Ujian) ==========
ws_form_approve = wb_form.create_sheet('APPROVE - Belum Ujian')

# Header
form_approve_cols = ['Nama Lengkap', 'NIM', 'Email', 'Email2', 'Email Final', 'Sumber', 'Subprogram', 'Rekomendasi']
for col_idx, col_name in enumerate(form_approve_cols, 1):
    cell = ws_form_approve.cell(row=1, column=col_idx, value=col_name)
    cell.fill = header_fill
    cell.font = header_font
    cell.alignment = Alignment(horizontal='center')
    cell.border = thin_border

# Data
if len(form_approve) > 0:
    for row_idx, row in enumerate(form_approve[form_approve_cols].values, 2):
        for col_idx, value in enumerate(row, 1):
            cell = ws_form_approve.cell(row=row_idx, column=col_idx, value=value)
            cell.fill = green_fill
            cell.border = thin_border
else:
    ws_form_approve.append([''] * len(form_approve_cols))
    ws_form_approve.cell(row=2, column=1, value="Tidak ada peserta yang layak di-approve")

# Auto-width
for col_idx, col_name in enumerate(form_approve_cols, 1):
    max_length = len(str(col_name))
    for row in ws_form_approve.iter_rows(min_row=2, min_col=col_idx, max_col=col_idx):
        for cell in row:
            if cell.value:
                max_length = max(max_length, len(str(cell.value)))
    ws_form_approve.column_dimensions[ws_form_approve.cell(row=1, column=col_idx).column_letter].width = min(max_length + 2, 50)

print(f"✅ Sheet 'APPROVE - Belum Ujian' dibuat ({len(form_approve)} peserta)")

# ========== SHEET 3: JANGAN APPROVE (Sudah Ujian) ==========
ws_form_reject = wb_form.create_sheet('JANGAN APPROVE - Sudah Ujian')

# Header
form_reject_cols = ['Nama Lengkap', 'NIM', 'Email', 'Email2', 'Email Final', 'Sumber', 'Subprogram', 
                    'Nama di Certiport', 'Skor Kecocokan', 'Rekomendasi']
for col_idx, col_name in enumerate(form_reject_cols, 1):
    cell = ws_form_reject.cell(row=1, column=col_idx, value=col_name)
    cell.fill = header_fill
    cell.font = header_font
    cell.alignment = Alignment(horizontal='center')
    cell.border = thin_border

# Data
if len(form_jangan_approve) > 0:
    for row_idx, row in enumerate(form_jangan_approve[form_reject_cols].values, 2):
        for col_idx, value in enumerate(row, 1):
            cell = ws_form_reject.cell(row=row_idx, column=col_idx, value=value)
            cell.fill = red_fill
            cell.border = thin_border
else:
    ws_form_reject.append([''] * len(form_reject_cols))
    ws_form_reject.cell(row=2, column=1, value="Tidak ada peserta yang sudah pernah ujian")

# Auto-width
for col_idx, col_name in enumerate(form_reject_cols, 1):
    max_length = len(str(col_name))
    for row in ws_form_reject.iter_rows(min_row=2, min_col=col_idx, max_col=col_idx):
        for cell in row:
            if cell.value:
                max_length = max(max_length, len(str(cell.value)))
    ws_form_reject.column_dimensions[ws_form_reject.cell(row=1, column=col_idx).column_letter].width = min(max_length + 2, 50)

print(f"✅ Sheet 'JANGAN APPROVE - Sudah Ujian' dibuat ({len(form_jangan_approve)} peserta)")

# ========== SHEET 4: Semua Hasil Form Keikutsertaan ==========
ws_all_form = wb_form.create_sheet('Semua Hasil Form')

# Header
all_form_cols = ['Nama Lengkap', 'NIM', 'Email', 'Email2', 'Email Final', 'Sumber', 'Subprogram', 
                 'Nama di Certiport', 'Skor Kecocokan', 'Status', 'Rekomendasi']
for col_idx, col_name in enumerate(all_form_cols, 1):
    cell = ws_all_form.cell(row=1, column=col_idx, value=col_name)
    cell.fill = header_fill
    cell.font = header_font
    cell.alignment = Alignment(horizontal='center')
    cell.border = thin_border

# Data - gabungkan semua hasil
for row_idx, row in enumerate(form_results_df[all_form_cols].values, 2):
    for col_idx, value in enumerate(row, 1):
        cell = ws_all_form.cell(row=row_idx, column=col_idx, value=value)
        # Warnai berdasarkan status
        status_val = str(ws_all_form.cell(row=row_idx, column=10).value)  # Kolom Status
        if "TIDAK DITEMUKAN" in status_val:
            cell.fill = green_fill
        elif "DITEMUKAN" in status_val:
            cell.fill = red_fill
        cell.border = thin_border

# Auto-width
for col_idx, col_name in enumerate(all_form_cols, 1):
    max_length = len(str(col_name))
    for row in ws_all_form.iter_rows(min_row=2, min_col=col_idx, max_col=col_idx):
        for cell in row:
            if cell.value:
                max_length = max(max_length, len(str(cell.value)))
    ws_all_form.column_dimensions[ws_all_form.cell(row=1, column=col_idx).column_letter].width = min(max_length + 2, 50)

print(f"✅ Sheet 'Semua Hasil Form' dibuat ({len(form_results_df)} peserta)")

# Save workbook TERPISAH untuk Form Keikutsertaan
form_excel_filename = 'HASIL_FORM_KEIKUTSERTAAN.xlsx'
wb_form.save(form_excel_filename)

print(f"\n{'=' * 80}")
print(f"✅ File Excel Form Keikutsertaan berhasil disimpan: {form_excel_filename}")
print(f"{'=' * 80}")
print("\n📋 DAFTAR SHEETS DALAM FILE EXCEL FORM KEIKUTSERTAAN:")
print(f"   1. Dashboard Summary          - Ringkasan Form Keikutsertaan")
print(f"   2. APPROVE - Belum Ujian      - 🟢 {len(form_approve)} peserta layak di-approve")
print(f"   3. JANGAN APPROVE - Sudah Ujian - 🔴 {len(form_jangan_approve)} peserta sudah pernah ujian")
print(f"   4. Semua Hasil Form           - Detail lengkap {len(form_results_df)} peserta")
print(f"\n💡 File ini TERPISAH dari file hasil filter peserta NOT APPROVED!")
print(f"   - File Peserta NOT APPROVED: HASIL_FILTER_PESERTA_LENGKAP.xlsx")
print(f"   - File Form Keikutsertaan  : {form_excel_filename}")
# Out:
# ================================================================================
# 📊 EXPORT HASIL FORM KEIKUTSERTAAN KE EXCEL (FILE TERPISAH)
# ================================================================================
# ✅ Sheet 'APPROVE - Belum Ujian' dibuat (24 peserta)
# ✅ Sheet 'JANGAN APPROVE - Sudah Ujian' dibuat (135 peserta)
# ✅ Sheet 'Semua Hasil Form' dibuat (159 peserta)
#
# ================================================================================
# ✅ File Excel Form Keikutsertaan berhasil disimpan: HASIL_FORM_KEIKUTSERTAAN.xlsx
# ================================================================================
#
# 📋 DAFTAR SHEETS DALAM FILE EXCEL FORM KEIKUTSERTAAN:
#    1. Dashboard Summary          - Ringkasan Form Keikutsertaan
#    2. APPROVE - Belum Ujian      - 🟢 24 peserta layak di-approve
#    3. JANGAN APPROVE - Sudah Ujian - 🔴 135 peserta sudah pernah ujian
#    4. Semua Hasil Form           - Detail lengkap 159 peserta
#
# 💡 File ini TERPISAH dari file hasil filter peserta NOT APPROVED!
#    - File Peserta NOT APPROVED: HASIL_FILTER_PESERTA_LENGKAP.xlsx
#    - File Form Keikutsertaan  : HASIL_FORM_KEIKUTSERTAAN.xlsx

# %%
# ========== FITUR PENCARIAN NAMA MANUAL ==========
print(f"\n{'=' * 70}")
print("🔎 FITUR PENCARIAN NAMA")
print(f"=" * 70)

def cari_nama(nama_peserta, sumber='ALL', threshold=70):
    """
    Mencari nama peserta di database Certiport
    
    Parameters:
    - nama_peserta: Nama yang ingin dicari
    - sumber: 'MCF', 'MOS', atau 'ALL' (default)
    - threshold: Batas minimum skor kecocokan (default 70)
    """
    print(f"\n{'=' * 70}")
    print(f"🔍 Mencari: {nama_peserta}")
    print(f"   Sumber: {sumber}")
    print(f"=" * 70)
    
    # Tentukan database yang akan dicari
    search_databases = []
    if sumber == 'MCF' or sumber == 'ALL':
        search_databases.append(('MCF (Azure AI-900)', certiport_mcf_names, certiport_mcf))
    if sumber == 'MOS' or sumber == 'ALL':
        search_databases.append(('MOS (Office 2019)', certiport_mos_names, certiport_mos))
    
    found_any = False
    all_similar = []
    
    for db_name, name_list, df_original in search_databases:
        print(f"\n--- Mencari di {db_name} ---")
        
        match, score, match_type = find_best_match(nama_peserta, name_list, threshold)
        
        if match:
            found_any = True
            print(f"✅ DITEMUKAN!")
            print(f"   Nama di Certiport: {match}")
            print(f"   Skor kecocokan: {score}")
            print(f"   Tipe match: {match_type}")
            
            # Cari detail di dataframe asli
            matched_rows = df_original[
                (df_original['First Name'].fillna('') + ' ' + df_original['Last Name'].fillna('')).apply(
                    lambda x: normalize_name(x) == match
                )
            ]
            
            if len(matched_rows) > 0:
                row = matched_rows.iloc[0]
                print(f"\n   📋 Detail dari Certiport:")
                print(f"      Exam: {row['Exam'] if 'Exam' in row else '-'}")
                print(f"      Result: {row['Result'] if 'Result' in row else '-'}")
                print(f"      Score: {row['Score'] if 'Score' in row else '-'}")
                print(f"      Exam Date: {row['Exam Date'] if 'Exam Date' in row else '-'}")
        else:
            print(f"❌ Tidak ditemukan dengan threshold {threshold}")
            print(f"   Skor tertinggi: {score}")
        
        # Kumpulkan nama-nama yang mirip
        for cert_name in name_list:
            scores = [
                fuzz.ratio(normalize_name(nama_peserta), cert_name),
                fuzz.token_set_ratio(normalize_name(nama_peserta), cert_name),
                fuzz.token_sort_ratio(normalize_name(nama_peserta), cert_name)
            ]
            max_score = max(scores)
            if max_score >= threshold - 20:
                all_similar.append((cert_name, max_score, db_name))
    
    # Tampilkan nama-nama yang mirip
    if not found_any and len(all_similar) > 0:
        print(f"\n{'=' * 70}")
        print(f"🔍 Nama-nama yang mirip (skor >= {threshold - 20}):")
        print(f"=" * 70)
        # Sort by score descending
        all_similar.sort(key=lambda x: x[1], reverse=True)
        for cert_name, sim_score, db_name in all_similar[:5]:  # Top 5
            print(f"   {sim_score:>3} | {cert_name} ({db_name})")
    
    if not found_any and len(all_similar) == 0:
        print(f"\n❌ Tidak ada nama yang mirip ditemukan")
        print(f"💡 Tips: Coba turunkan threshold atau periksa ejaan nama")
    
    print(f"\n{'=' * 70}")

print("✅ Fungsi cari_nama() siap digunakan!")
print("\n📖 Cara menggunakan:")
print("   1. cari_nama('NAMA LENGKAP')               → Cari di MCF & MOS")
print("   2. cari_nama('NAMA LENGKAP', 'MCF')        → Cari di MCF saja")
print("   3. cari_nama('NAMA LENGKAP', 'MOS')        → Cari di MOS saja")
print("   4. cari_nama('NAMA LENGKAP', threshold=60) → Threshold lebih rendah")
print("\n🔍 Contoh:")
print("   cari_nama('LILY FITRI HASANAH')")
print("   cari_nama('MUHAMMAD REVIANSYAH', 'MCF')")
# Out:
# ======================================================================
# 🔎 FITUR PENCARIAN NAMA
# ======================================================================
# ✅ Fungsi cari_nama() siap digunakan!
#
# 📖 Cara menggunakan:
#    1. cari_nama('NAMA LENGKAP')               → Cari di MCF & MOS
#    2. cari_nama('NAMA LENGKAP', 'MCF')        → Cari di MCF saja
#    3. cari_nama('NAMA LENGKAP', 'MOS')        → Cari di MOS saja
#    4. cari_nama('NAMA LENGKAP', threshold=60) → Threshold lebih rendah
#
# 🔍 Contoh:
#    cari_nama('LILY FITRI HASANAH')
#    cari_nama('MUHAMMAD REVIANSYAH', 'MCF')

# %%
cari_nama('yohanes alvin')
# Out:
# ======================================================================
# 🔍 Mencari: yohanes alvin
#    Sumber: ALL
# ======================================================================
#
# --- Mencari di MCF (Azure AI-900) ---
# ❌ Tidak ditemukan dengan threshold 70
#    Skor tertinggi: 0
#
# --- Mencari di MOS (Office 2019) ---
# ❌ Tidak ditemukan dengan threshold 70
#    Skor tertinggi: 0
#
# ======================================================================
# 🔍 Nama-nama yang mirip (skor >= 50):
# ======================================================================
#     70 | YOHANES TRI SUGIARTO (MCF (Azure AI-900))
#     70 | YOHANES ANDREAN SIMANJUNTAK (MOS (Office 2019))
#     70 | YOHANES KEVIN SINAGA (MOS (Office 2019))
#     62 | JOHANNES SARAGIH (MOS (Office 2019))
#     62 | YOHANA SANAOU (MOS (Office 2019))
#
# ======================================================================
